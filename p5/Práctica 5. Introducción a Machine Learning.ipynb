# %% [markdown]
# # Introducción a Machine Learning
#
# Los procesos principales en Machine Learning  son los siguientes:
# 1. Recolección de datos
#
# 2. Procesamiento de datos
#
# 3. Identificación del modelo
#
# 4. Entrenamiento
#
# 5. Validación
#
# 6. Identificación de hiperparámetros
#
# 7. Predicción
#
#
#
# El proceso de aprendizaje es iterativo, por lo que es común que en cualquier paso nos podamos regresar a otro proceso, siempre con la finalidad de generar el mejor modelo.
#
# En esta práctica partiremos del punto 2, asumiendo que los datos ya están recolectados.

# %% [markdown]
# ## 2. procesamiento de datos

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

diabetes = datasets.load_diabetes()
X = diabetes.data
y = diabetes.target

print('Dimensiones en X = {}'.format(X.shape))
print('Dimensiones en y = {}'.format(y.shape))

# Samples total  442
# Dimensionality  10
# Features  real, -.2 < x < .2
# Targets integer 25 - 346
# Out:
# Dimensiones en X = (442, 10)
# Dimensiones en y = (442,)

# %% [markdown]
# ## 3. Identificación del modelo
#
# En este ejemplo se seleccionará  el modelo Lasso

# %%
from sklearn.linear_model import Lasso

linear_model = Lasso()

# %% [markdown]
# ## 4 y 5. Entrenamiento y Validación

# %%
from sklearn.model_selection import KFold

k_fold = KFold(n_splits=3)

for k, (train, test) in enumerate(k_fold.split(X, y)):
    # Se entrena con el conjunto de datos de entrenamiento
    linear_model.fit(X[train], y[train])
    # Se valida con el conjunto de datos de prueba
    print("[fold {}]  coeficiente de correlación: {}".format(k, linear_model.score(X[test], y[test])))
# Out:
# [fold 0]  coeficiente de correlación: 0.3454298483368484
# [fold 1]  coeficiente de correlación: 0.34712314449919834
# [fold 2]  coeficiente de correlación: 0.36884725706191346

# %% [markdown]
# ## 6. Identificación de hiperparámetros
#
# El modelo Lasso tiene un hiperparámetro que es alpha, por defecto tiene asignado el valor 1.0.
#
# Para identificar de qué forma se deberían modificar los hiperparámetros para aumentar el rendimiento, se debe conocer muy bien el algoritmo.
#
# Esta práctica tiene como objetivo el de conocer los procesos generales en el aprendizaje automático, así que la explicación del modelo está fuera de este ámbito. Sin embargo, se muestra la función objetivo para dar una intuición de cómo afecta éste hiperparámetro en el modelo.
#
# $$ Cost = (1 / (2 * num\_instancias)) * ||y - Xw||^2_2 + alpha * ||w||_1$$

# %%
linear_model2 = Lasso(alpha=0.1)
k_fold = KFold(n_splits=3)

for k, (train, test) in enumerate(k_fold.split(X, y)):
    # Se entrena con el conjunto de datos de entrenamiento
    linear_model2.fit(X[train], y[train])
    # Se valida con el conjunto de datos de prueba
    print("[fold {}]  coeficiente de correlación: {}".format(k, linear_model2.score(X[test], y[test])))
# Out:
# [fold 0]  coeficiente de correlación: 0.4553764654572192
# [fold 1]  coeficiente de correlación: 0.4970449650050526
# [fold 2]  coeficiente de correlación: 0.5075811884365067

# %% [markdown]
# # Ejercicio 1
#
# 1.1 Automatizar la búsqueda del mejor valor de alpha. Por ejemplo, realizar una búsqueda de 50 elementos en el rango [0,1]
#
# Emplear validación cruzada de 4 folds
#
# 1.2 Discutir cómo afecta el número de folds en el proceso de entrenamiento y validación; cuál valor es el adecuado.

# %%
#*EXTRA
def frange(start,stop,step):
    while(start<stop):
        yield start
        start = start+step

# %%
#Ejercicio 1.1 Busqueda del Alpha !!
n = 4
k_fold2 = KFold(n_splits=n)
AALPHA = 0
KALPHA = 0
IALPHA = 0
for i in frange(0.02,1,.02):
    AALPHA = 0
    print("alpha = {}".format(i))
    linear_model3 = Lasso(alpha = i)
    for k2, (train, test) in enumerate(k_fold2.split(X, y)):
        linear_model3.fit(X[train], y[train])
        # Se valida con el conjunto de datos de prueba
        print("[fold {}]  coeficiente de correlación: {}".format(k2, linear_model3.score(X[test], y[test])))
        AALPHA = AALPHA + (linear_model3.score(X[test],y[test]))    
    print(AALPHA/4)
    if(KALPHA == 0):
        KALPHA = (AALPHA/4)
    else:
        if(KALPHA < (AALPHA/4)):
            print("Mejor coeficiente previo: {} ".format(KALPHA))
            print("Coeficiente actual: {} ".format(AALPHA/4))
            IALPHA = i
            KALPHA = (AALPHA/4)
print("Mejor alpha en promedio {} con un coeficiente de correlacion de : {}".format(IALPHA,KALPHA))
# Out:
# alpha = 0.02
# [fold 0]  coeficiente de correlación: 0.3769289242773214
# [fold 1]  coeficiente de correlación: 0.491627611130961
# [fold 2]  coeficiente de correlación: 0.5190668895489858
# [fold 3]  coeficiente de correlación: 0.5520232571489545
# 0.48491167052655565
# alpha = 0.04
# [fold 0]  coeficiente de correlación: 0.3740694525340482
# [fold 1]  coeficiente de correlación: 0.491319297812412
# [fold 2]  coeficiente de correlación: 0.5232127006233358
# [fold 3]  coeficiente de correlación: 0.5505138199236015
# 0.4847788177233494
# alpha = 0.06
# [fold 0]  coeficiente de correlación: 0.3712448906760034
# [fold 1]  coeficiente de correlación: 0.4899057395240403
# [fold 2]  coeficiente de correlación: 0.5260674943874821
# [fold 3]  coeficiente de correlación: 0.5492321090698324
# 0.4841125584143396
# alpha = 0.08
# [fold 0]  coeficiente de correlación: 0.3681075893657214
# [fold 1]  coeficiente de correlación: 0.4879878655074767
# [fold 2]  coeficiente de correlación: 0.5272153255204881
# [fold 3]  coeficiente de correlación: 0.5463826281783588
# 0.48242335214301124
# alpha = 0.1
# [fold 0]  coeficiente de correlación: 0.3644958015494224
# [fold 1]  coeficiente de correlación: 0.48556483255372984
# [fold 2]  coeficiente de correlación: 0.5272174060509351
# [fold 3]  coeficiente de correlación: 0.5438047541733582
# 0.4802706985818614
# alpha = 0.12000000000000001
# [fold 0]  coeficiente de correlación: 0.3606869258514913
# [fold 1]  coeficiente de correlación: 0.4824232867942369
# [fold 2]  coeficiente de correlación: 0.5268683850546566
# [fold 3]  coeficiente de correlación: 0.5413152987795158
# 0.47782347411997517
# alpha = 0.14
# [fold 0]  coeficiente de correlación: 0.3592612132086467
# [fold 1]  coeficiente de correlación: 0.4794689685503007
# [fold 2]  coeficiente de correlación: 0.5261707808886207
# [fold 3]  coeficiente de correlación: 0.5382783545011129
# 0.47579482928717026
# alpha = 0.16
# [fold 0]  coeficiente de correlación: 0.3575702534500782
# [fold 1]  coeficiente de correlación: 0.47699344472200234
# [fold 2]  coeficiente de correlación: 0.5251239149273819
# [fold 3]  coeficiente de correlación: 0.5346945177868268
# 0.4735955327215723
# alpha = 0.18
# [fold 0]  coeficiente de correlación: 0.35561325132640675
# [fold 1]  coeficiente de correlación: 0.47448502054195
# [fold 2]  coeficiente de correlación: 0.5237268201148249
# [fold 3]  coeficiente de correlación: 0.5309882216829112
# 0.4712033284165232
# alpha = 0.19999999999999998
# [fold 0]  coeficiente de correlación: 0.35339019816200623
# [fold 1]  coeficiente de correlación: 0.4716965335399377
# [fold 2]  coeficiente de correlación: 0.5219817457424014
# [fold 3]  coeficiente de correlación: 0.5274493289383079
# 0.46862945159566327
# alpha = 0.21999999999999997
# [fold 0]  coeficiente de correlación: 0.35090106266498045
# [fold 1]  coeficiente de correlación: 0.46862731755943043
# [fold 2]  coeficiente de correlación: 0.5198262222889101
# [fold 3]  coeficiente de correlación: 0.5235915118027251
# 0.4657365285790115
# alpha = 0.23999999999999996
# [fold 0]  coeficiente de correlación: 0.3481458782511987
# [fold 1]  coeficiente de correlación: 0.4652830353790172
# [fold 2]  coeficiente de correlación: 0.5172497747463913
# [fold 3]  coeficiente de correlación: 0.5194086331139218
# 0.4625218303726323
# alpha = 0.25999999999999995
# [fold 0]  coeficiente de correlación: 0.34620274381520455
# [fold 1]  coeficiente de correlación: 0.4616609203265224
# [fold 2]  coeficiente de correlación: 0.5143512846845586
# [fold 3]  coeficiente de correlación: 0.5149059217963102
# 0.45928021765564897
# alpha = 0.27999999999999997
# [fold 0]  coeficiente de correlación: 0.34698199904970795
# [fold 1]  coeficiente de correlación: 0.45776097240194585
# [fold 2]  coeficiente de correlación: 0.5111326279697568
# [fold 3]  coeficiente de correlación: 0.5101000541206504
# 0.45649391338551526
# alpha = 0.3
# [fold 0]  coeficiente de correlación: 0.3476139608027433
# [fold 1]  coeficiente de correlación: 0.4541665492799456
# [fold 2]  coeficiente de correlación: 0.5075900483533456
# [fold 3]  coeficiente de correlación: 0.5072736605829902
# 0.4541610547547562
# alpha = 0.32
# [fold 0]  coeficiente de correlación: 0.34810154900163703
# [fold 1]  coeficiente de correlación: 0.4521184480882562
# [fold 2]  coeficiente de correlación: 0.5037253909609968
# [fold 3]  coeficiente de correlación: 0.5047504042053929
# 0.45217394806407074
# alpha = 0.34
# [fold 0]  coeficiente de correlación: 0.3484432323166544
# [fold 1]  coeficiente de correlación: 0.44996051082001115
# [fold 2]  coeficiente de correlación: 0.4995542879865912
# [fold 3]  coeficiente de correlación: 0.502101447377367
# 0.4500148696251559
# alpha = 0.36000000000000004
# [fold 0]  coeficiente de correlación: 0.3486390083081835
# [fold 1]  coeficiente de correlación: 0.44769140559269605
# [fold 2]  coeficiente de correlación: 0.4963784688397441
# [fold 3]  coeficiente de correlación: 0.49932721939564406
# 0.44800902553406696
# alpha = 0.38000000000000006
# [fold 0]  coeficiente de correlación: 0.34868887666851267
# [fold 1]  coeficiente de correlación: 0.44531110919322353
# [fold 2]  coeficiente de correlación: 0.49308300230108587
# [fold 3]  coeficiente de correlación: 0.4964275963119755
# 0.4458776461186994
# alpha = 0.4000000000000001
# [fold 0]  coeficiente de correlación: 0.34859283739764213
# [fold 1]  coeficiente de correlación: 0.44281962162159433
# [fold 2]  coeficiente de correlación: 0.4896684136446123
# [fold 3]  coeficiente de correlación: 0.49340245835389346
# 0.44362083275443553
# alpha = 0.4200000000000001
# [fold 0]  coeficiente de correlación: 0.34835089049557133
# [fold 1]  coeficiente de correlación: 0.440216942877808
# [fold 2]  coeficiente de correlación: 0.48613461043294937
# [fold 3]  coeficiente de correlación: 0.49025176480033744
# 0.4412385521516665
# alpha = 0.4400000000000001
# [fold 0]  coeficiente de correlación: 0.3479630359623008
# [fold 1]  coeficiente de correlación: 0.43750307296186447
# [fold 2]  coeficiente de correlación: 0.48248155567616774
# [fold 3]  coeficiente de correlación: 0.48697551440088044
# 0.43873079475030335
# alpha = 0.46000000000000013
# [fold 0]  coeficiente de correlación: 0.3474293402626649
# [fold 1]  coeficiente de correlación: 0.4346780118737642
# [fold 2]  coeficiente de correlación: 0.4787092493742667
# [fold 3]  coeficiente de correlación: 0.4835737071555225
# 0.4360975771665546
# alpha = 0.48000000000000015
# [fold 0]  coeficiente de correlación: 0.34674979804104855
# [fold 1]  coeficiente de correlación: 0.4317417596135065
# [fold 2]  coeficiente de correlación: 0.4748176915272462
# [fold 3]  coeficiente de correlación: 0.480046343064264
# 0.4333388980615163
# alpha = 0.5000000000000001
# [fold 0]  coeficiente de correlación: 0.34587155086910726
# [fold 1]  coeficiente de correlación: 0.42869431618109205
# [fold 2]  coeficiente de correlación: 0.4708068821351068
# [fold 3]  coeficiente de correlación: 0.47639342212710467
# 0.4304415428281027
# alpha = 0.5200000000000001
# [fold 0]  coeficiente de correlación: 0.3445492882218246
# [fold 1]  coeficiente de correlación: 0.4255356815765203
# [fold 2]  coeficiente de correlación: 0.4666768211978481
# [fold 3]  coeficiente de correlación: 0.47261494434404455
# 0.4273441838350594
# alpha = 0.5400000000000001
# [fold 0]  coeficiente de correlación: 0.34308461284265646
# [fold 1]  coeficiente de correlación: 0.4222658557997916
# [fold 2]  coeficiente de correlación: 0.4624275087154703
# [fold 3]  coeficiente de correlación: 0.4687109097150834
# 0.42412222176825043
# alpha = 0.5600000000000002
# [fold 0]  coeficiente de correlación: 0.34147760767425717
# [fold 1]  coeficiente de correlación: 0.4188848388509062
# [fold 2]  coeficiente de correlación: 0.45805894468797353
# [fold 3]  coeficiente de correlación: 0.4646813182402218
# 0.4207756773633397
# alpha = 0.5800000000000002
# [fold 0]  coeficiente de correlación: 0.33972827271662687
# [fold 1]  coeficiente de correlación: 0.41539263072986365
# [fold 2]  coeficiente de correlación: 0.453571129115357
# [fold 3]  coeficiente de correlación: 0.46052616991945927
# 0.4173045506203267
# alpha = 0.6000000000000002
# [fold 0]  coeficiente de correlación: 0.33783660796976545
# [fold 1]  coeficiente de correlación: 0.41178923143666374
# [fold 2]  coeficiente de correlación: 0.4489640553746741
# [fold 3]  coeficiente de correlación: 0.4562454647527961
# 0.41370883988347484
# alpha = 0.6200000000000002
# [fold 0]  coeficiente de correlación: 0.33580261343367257
# [fold 1]  coeficiente de correlación: 0.4080746409713071
# [fold 2]  coeficiente de correlación: 0.44423771650669974
# [fold 3]  coeficiente de correlación: 0.4518392027402321
# 0.40998854341297786
# alpha = 0.6400000000000002
# [fold 0]  coeficiente de correlación: 0.333626289108349
# [fold 1]  coeficiente de correlación: 0.40424885933379306
# [fold 2]  coeficiente de correlación: 0.4399506829387572
# [fold 3]  coeficiente de correlación: 0.44730738388176705
# 0.4062833038156666
# alpha = 0.6600000000000003
# [fold 0]  coeficiente de correlación: 0.3313076349937938
# [fold 1]  coeficiente de correlación: 0.4003118865241222
# [fold 2]  coeficiente de correlación: 0.43587772226993204
# [fold 3]  coeficiente de correlación: 0.44265000817740136
# 0.4025368129913124
# alpha = 0.6800000000000003
# [fold 0]  coeficiente de correlación: 0.3288466510900079
# [fold 1]  coeficiente de correlación: 0.3962637225422943
# [fold 2]  coeficiente de correlación: 0.4317044125682866
# [fold 3]  coeficiente de correlación: 0.4378670756271351
# 0.39867046545693097
# alpha = 0.7000000000000003
# [fold 0]  coeficiente de correlación: 0.3262433373969905
# [fold 1]  coeficiente de correlación: 0.39246221891249233
# [fold 2]  coeficiente de correlación: 0.4274352253599109
# [fold 3]  coeficiente de correlación: 0.4329585550072058
# 0.39477483416914994
# alpha = 0.7200000000000003
# [fold 0]  coeficiente de correlación: 0.32349769391474226
# [fold 1]  coeficiente de correlación: 0.3888611374141713
# [fold 2]  coeficiente de correlación: 0.42306775117296913
# [fold 3]  coeficiente de correlación: 0.4280515081405349
# 0.3908695226606044
# alpha = 0.7400000000000003
# [fold 0]  coeficiente de correlación: 0.32060972064326276
# [fold 1]  coeficiente de correlación: 0.38516317301079817
# [fold 2]  coeficiente de correlación: 0.41860212099274385
# [fold 3]  coeficiente de correlación: 0.4235087128584844
# 0.3869709318763223
# alpha = 0.7600000000000003
# [fold 0]  coeficiente de correlación: 0.3175794121869995
# [fold 1]  coeficiente de correlación: 0.38136703477488076
# [fold 2]  coeficiente de correlación: 0.4140383356141854
# [fold 3]  coeficiente de correlación: 0.41885446163855433
# 0.382959811053655
# alpha = 0.7800000000000004
# [fold 0]  coeficiente de correlación: 0.3144067705068079
# [fold 1]  coeficiente de correlación: 0.37747280301482455
# [fold 2]  coeficiente de correlación: 0.4093763964475514
# [fold 3]  coeficiente de correlación: 0.4140888130916839
# 0.3788361957652169
# alpha = 0.8000000000000004
# [fold 0]  coeficiente de correlación: 0.3110920949764988
# [fold 1]  coeficiente de correlación: 0.37348056195665846
# [fold 2]  coeficiente de correlación: 0.4046163581810502
# [fold 3]  coeficiente de correlación: 0.4092116851191759
# 0.3746001750583458
# alpha = 0.8200000000000004
# [fold 0]  coeficiente de correlación: 0.3077113797946812
# [fold 1]  coeficiente de correlación: 0.36939023063104404
# [fold 2]  coeficiente de correlación: 0.3997581687404611
# [fold 3]  coeficiente de correlación: 0.40422307772103006
# 0.37027071422180413
# alpha = 0.8400000000000004
# [fold 0]  coeficiente de correlación: 0.3046475232937993
# [fold 1]  coeficiente de correlación: 0.3652018090379814
# [fold 2]  coeficiente de correlación: 0.39480182812578435
# [fold 3]  coeficiente de correlación: 0.3991230035281656
# 0.36594354099643267
# alpha = 0.8600000000000004
# [fold 0]  coeficiente de correlación: 0.3014737937478621
# [fold 1]  coeficiente de correlación: 0.3609152971774705
# [fold 2]  coeficiente de correlación: 0.3897473363370195
# [fold 3]  coeficiente de correlación: 0.39468610539409393
# 0.36170563316411153
# alpha = 0.8800000000000004
# [fold 0]  coeficiente de correlación: 0.2981904857584198
# [fold 1]  coeficiente de correlación: 0.3565306950495113
# [fold 2]  coeficiente de correlación: 0.3845946933741668
# [fold 3]  coeficiente de correlación: 0.39061614973429387
# 0.35748300597909793
# alpha = 0.9000000000000005
# [fold 0]  coeficiente de correlación: 0.2947976007228278
# [fold 1]  coeficiente de correlación: 0.35204800265410374
# [fold 2]  coeficiente de correlación: 0.37934389923722656
# [fold 3]  coeficiente de correlación: 0.38645130487850604
# 0.35316020187316605
# alpha = 0.9200000000000005
# [fold 0]  coeficiente de correlación: 0.29129516536781164
# [fold 1]  coeficiente de correlación: 0.34746721999124786
# [fold 2]  coeficiente de correlación: 0.3739949887795133
# [fold 3]  coeficiente de correlación: 0.3821909759595369
# 0.34873708752452737
# alpha = 0.9400000000000005
# [fold 0]  coeficiente de correlación: 0.28768314893785163
# [fold 1]  coeficiente de correlación: 0.34278835603609414
# [fold 2]  coeficiente de correlación: 0.36927114551598517
# [fold 3]  coeficiente de correlación: 0.3778357886139615
# 0.34439460977597314
# alpha = 0.9600000000000005
# [fold 0]  coeficiente de correlación: 0.28396155143294743
# [fold 1]  coeficiente de correlación: 0.33801141484965636
# [fold 2]  coeficiente de correlación: 0.36469072820128956
# [fold 3]  coeficiente de correlación: 0.3733841376495943
# 0.3400119580333719
# alpha = 0.9800000000000005
# [fold 0]  coeficiente de correlación: 0.2801303728530986
# [fold 1]  coeficiente de correlación: 0.3331363843209304
# [fold 2]  coeficiente de correlación: 0.3600225995190942
# [fold 3]  coeficiente de correlación: 0.3688403180385743
# 0.3355324186829244
# Mejor alpha en promedio 0 con un coeficiente de correlacion de : 0.48491167052655565

# %% [markdown]
# # Ejercicio 2
#
# Programar los siguientes errores: $sse$, $mse$, $rmse$
#
# Agregar las métricas en el proceso de validación del modelo

# %%
def SSEf(Yr,Yi):
    return (Yr-Yi)**2
    
def SSE(Yr,Yi):
    Sum = 0
    for i in range(0,len(Yr)):
        Sum = Sum + SSEf(Yr[i],Yi[i])    
        

def MSE(Yr,Yi):
    n = len(Yr)
    Y = SSE(Yr,Yi)
    return (Y/n)

def RMSE(Yr,Yi):
    return MSE(Yr,Yi)**.5

# %% [markdown]
# # Ejercicio 3
# Graficar los valores obtenidos por el modelo, con el mejor hiper-parámetro, y los valores reales de cada uno de los folds.

# %% [markdown]
# # Ejercicio 4
#
# Replicar los ejercicios 1, 2 y 3 con el dataset boston.
#
# Ejemplo:

# %%
from sklearn.datasets import load_boston
boston = load_boston()
Z = boston.data
a = boston.target

# %%
n = 4 
k_fold3 = KFold(n_splits=n)
AALPHA = 0
KALPHA = 0
IALPHA = 0
for i in frange(0.02,1,.02):
    AALPHA = 0
    print("alpha = {}".format(i))
    linear_model4 = Lasso(alpha = i)
    for k2, (train, test) in enumerate(k_fold3.split(Z, a)):
        linear_model4.fit(Z[train], a[train])
        # Se valida con el conjunto de datos de prueba
        print("[fold {}]  coeficiente de correlación: {}".format(k2, linear_model4.score(Z[test], a[test])))
        AALPHA = AALPHA + (linear_model4.score(Z[test],a[test]))    
    print(AALPHA/4)
    if(KALPHA == 0):
        KALPHA = (AALPHA/4)
    else:
        if(KALPHA < (AALPHA/4)):
            print("Mejor coeficiente previo: {} ".format(KALPHA))
            print("Coeficiente actual: {} ".format(AALPHA/4))
            IALPHA = i
            KALPHA = (AALPHA/4)
print("Mejor alpha en promedio {} con un coeficiente de correlacion promedio de : {}".format(IALPHA,KALPHA))
# Out:
# alpha = 0.02
# [fold 0]  coeficiente de correlación: 0.6213988695064239
# [fold 1]  coeficiente de correlación: 0.6064232922012476
# [fold 2]  coeficiente de correlación: 0.35765810694009037
# [fold 3]  coeficiente de correlación: -0.9966977838336577
# 0.14719562120352603
# alpha = 0.04
# [fold 0]  coeficiente de correlación: 0.6367945805750947
# [fold 1]  coeficiente de correlación: 0.5860427085338555
# [fold 2]  coeficiente de correlación: 0.35500454255540204
# [fold 3]  coeficiente de correlación: -0.8966285273516204
# 0.170303326078183
# Mejor coeficiente previo: 0.14719562120352603
# Coeficiente actual: 0.170303326078183
# alpha = 0.06
# [fold 0]  coeficiente de correlación: 0.6482717484265264
# [fold 1]  coeficiente de correlación: 0.5908239413244163
# [fold 2]  coeficiente de correlación: 0.3559220347040888
# [fold 3]  coeficiente de correlación: -0.8848802365116797
# 0.17753437198583794
# Mejor coeficiente previo: 0.170303326078183
# Coeficiente actual: 0.17753437198583794
# alpha = 0.08
# [fold 0]  coeficiente de correlación: 0.6547833728640053
# [fold 1]  coeficiente de correlación: 0.5953513334718732
# [fold 2]  coeficiente de correlación: 0.35939461933885175
# [fold 3]  coeficiente de correlación: -0.8804069950222624
# 0.18228058266311697
# Mejor coeficiente previo: 0.17753437198583794
# Coeficiente actual: 0.18228058266311697
# alpha = 0.1
# [fold 0]  coeficiente de correlación: 0.6534236080400266
# [fold 1]  coeficiente de correlación: 0.5989522436842125
# [fold 2]  coeficiente de correlación: 0.3627376057059422
# [fold 3]  coeficiente de correlación: -0.857080480510237
# 0.18950824422998608
# Mejor coeficiente previo: 0.18228058266311697
# Coeficiente actual: 0.18950824422998608
# alpha = 0.12000000000000001
# [fold 0]  coeficiente de correlación: 0.6518379433628849
# [fold 1]  coeficiente de correlación: 0.6016260884501182
# [fold 2]  coeficiente de correlación: 0.3659538568002785
# [fold 3]  coeficiente de correlación: -0.8369212606702552
# 0.19562415698575658
# Mejor coeficiente previo: 0.18950824422998608
# Coeficiente actual: 0.19562415698575658
# alpha = 0.14
# [fold 0]  coeficiente de correlación: 0.6500268132634917
# [fold 1]  coeficiente de correlación: 0.6033740077709451
# [fold 2]  coeficiente de correlación: 0.3690400675208582
# [fold 3]  coeficiente de correlación: -0.818743030037455
# 0.20092446462946
# Mejor coeficiente previo: 0.19562415698575658
# Coeficiente actual: 0.20092446462946
# alpha = 0.16
# [fold 0]  coeficiente de correlación: 0.6479898566192559
# [fold 1]  coeficiente de correlación: 0.6041954273786496
# [fold 2]  coeficiente de correlación: 0.37199338103335394
# [fold 3]  coeficiente de correlación: -0.8033161875472543
# 0.2052156193710013
# Mejor coeficiente previo: 0.20092446462946
# Coeficiente actual: 0.2052156193710013
# alpha = 0.18
# [fold 0]  coeficiente de correlación: 0.6457272434900733
# [fold 1]  coeficiente de correlación: 0.6040895967860944
# [fold 2]  coeficiente de correlación: 0.37482056885290305
# [fold 3]  coeficiente de correlación: -0.7906202968938973
# 0.2085042780587934
# Mejor coeficiente previo: 0.2052156193710013
# Coeficiente actual: 0.2085042780587934
# alpha = 0.19999999999999998
# [fold 0]  coeficiente de correlación: 0.6437745108029724
# [fold 1]  coeficiente de correlación: 0.6030580389631042
# [fold 2]  coeficiente de correlación: 0.3775179543455275
# [fold 3]  coeficiente de correlación: -0.7806455869259596
# 0.21092622929641114
# Mejor coeficiente previo: 0.2085042780587934
# Coeficiente actual: 0.21092622929641114
# alpha = 0.21999999999999997
# [fold 0]  coeficiente de correlación: 0.6424300508498404
# [fold 1]  coeficiente de correlación: 0.60109915543788
# [fold 2]  coeficiente de correlación: 0.38008214638641014
# [fold 3]  coeficiente de correlación: -0.7733767420458755
# 0.21255865265706375
# Mejor coeficiente previo: 0.21092622929641114
# Coeficiente actual: 0.21255865265706375
# alpha = 0.23999999999999996
# [fold 0]  coeficiente de correlación: 0.6410163465264317
# [fold 1]  coeficiente de correlación: 0.5975392337617416
# [fold 2]  coeficiente de correlación: 0.38252013746316116
# [fold 3]  coeficiente de correlación: -0.7688359580132378
# 0.2130599399345242
# Mejor coeficiente previo: 0.21255865265706375
# Coeficiente actual: 0.2130599399345242
# alpha = 0.25999999999999995
# [fold 0]  coeficiente de correlación: 0.6395336470704847
# [fold 1]  coeficiente de correlación: 0.5934408570667068
# [fold 2]  coeficiente de correlación: 0.3848280445854779
# [fold 3]  coeficiente de correlación: -0.7670091495838764
# 0.21269834978469826
# alpha = 0.27999999999999997
# [fold 0]  coeficiente de correlación: 0.637981609156379
# [fold 1]  coeficiente de correlación: 0.589302537285521
# [fold 2]  coeficiente de correlación: 0.3870023822729546
# [fold 3]  coeficiente de correlación: -0.7680001568178254
# 0.21157159297425726
# alpha = 0.3
# [fold 0]  coeficiente de correlación: 0.636360393361469
# [fold 1]  coeficiente de correlación: 0.5851232028485278
# [fold 2]  coeficiente de correlación: 0.38905064444361204
# [fold 3]  coeficiente de correlación: -0.7739989840541484
# 0.20913381414986515
# alpha = 0.32
# [fold 0]  coeficiente de correlación: 0.6346703233893551
# [fold 1]  coeficiente de correlación: 0.5809016678134955
# [fold 2]  coeficiente de correlación: 0.3909683606923624
# [fold 3]  coeficiente de correlación: -0.782373209216487
# 0.2060417856696815
# alpha = 0.34
# [fold 0]  coeficiente de correlación: 0.6329107779615064
# [fold 1]  coeficiente de correlación: 0.5766402719521185
# [fold 2]  coeficiente de correlación: 0.39275611387987547
# [fold 3]  coeficiente de correlación: -0.7916666284971836
# 0.2026601338240792
# alpha = 0.36000000000000004
# [fold 0]  coeficiente de correlación: 0.6310819893012758
# [fold 1]  coeficiente de correlación: 0.5723378649052404
# [fold 2]  coeficiente de correlación: 0.39441407379238225
# [fold 3]  coeficiente de correlación: -0.8032035786472622
# 0.19865758733790906
# alpha = 0.38000000000000006
# [fold 0]  coeficiente de correlación: 0.6291844180819811
# [fold 1]  coeficiente de correlación: 0.5679944466728624
# [fold 2]  coeficiente de correlación: 0.39594218079275784
# [fold 3]  coeficiente de correlación: -0.7939202562863984
# 0.19980019731530071
# alpha = 0.4000000000000001
# [fold 0]  coeficiente de correlación: 0.6271360806894027
# [fold 1]  coeficiente de correlación: 0.5636086335716328
# [fold 2]  coeficiente de correlación: 0.3973405539813812
# [fold 3]  coeficiente de correlación: -0.7747137374541215
# 0.20334288269707385
# alpha = 0.4200000000000001
# [fold 0]  coeficiente de correlación: 0.6250320257184773
# [fold 1]  coeficiente de correlación: 0.5591832926581639
# [fold 2]  coeficiente de correlación: 0.39860923897738315
# [fold 3]  coeficiente de correlación: -0.7557296746492181
# 0.20677372067620153
# alpha = 0.4400000000000001
# [fold 0]  coeficiente de correlación: 0.6228761202738982
# [fold 1]  coeficiente de correlación: 0.5547169443329021
# [fold 2]  coeficiente de correlación: 0.399747994260226
# [fold 3]  coeficiente de correlación: -0.7369795620961077
# 0.21009037419272963
# alpha = 0.46000000000000013
# [fold 0]  coeficiente de correlación: 0.6206683847320178
# [fold 1]  coeficiente de correlación: 0.5502095869823231
# [fold 2]  coeficiente de correlación: 0.4007567967794954
# [fold 3]  coeficiente de correlación: -0.7184538575642636
# 0.21329522773239318
# Mejor coeficiente previo: 0.2130599399345242
# Coeficiente actual: 0.21329522773239318
# alpha = 0.48000000000000015
# [fold 0]  coeficiente de correlación: 0.6184193001844019
# [fold 1]  coeficiente de correlación: 0.5456596451978788
# [fold 2]  coeficiente de correlación: 0.40164754749077164
# [fold 3]  coeficiente de correlación: -0.7001518004221714
# 0.2163936731127203
# Mejor coeficiente previo: 0.21329522773239318
# Coeficiente actual: 0.2163936731127203
# alpha = 0.5000000000000001
# [fold 0]  coeficiente de correlación: 0.6161976779073557
# [fold 1]  coeficiente de correlación: 0.5410703308187159
# [fold 2]  coeficiente de correlación: 0.4024514815888209
# [fold 3]  coeficiente de correlación: -0.6820699770500513
# 0.2194123783162103
# Mejor coeficiente previo: 0.2163936731127203
# Coeficiente actual: 0.2194123783162103
# alpha = 0.5200000000000001
# [fold 0]  coeficiente de correlación: 0.6139150917908169
# [fold 1]  coeficiente de correlación: 0.5364385234948066
# [fold 2]  coeficiente de correlación: 0.4031328828736903
# [fold 3]  coeficiente de correlación: -0.6642070752656692
# 0.22231985572341112
# Mejor coeficiente previo: 0.2194123783162103
# Coeficiente actual: 0.22231985572341112
# alpha = 0.5400000000000001
# [fold 0]  coeficiente de correlación: 0.611571388556201
# [fold 1]  coeficiente de correlación: 0.5331991258978623
# [fold 2]  coeficiente de correlación: 0.40368330670676017
# [fold 3]  coeficiente de correlación: -0.6465760035516073
# 0.22546945440230404
# Mejor coeficiente previo: 0.22231985572341112
# Coeficiente actual: 0.22546945440230404
# alpha = 0.5600000000000002
# [fold 0]  coeficiente de correlación: 0.6091959585966241
# [fold 1]  coeficiente de correlación: 0.5326247835178552
# [fold 2]  coeficiente de correlación: 0.40411328051126355
# [fold 3]  coeficiente de correlación: -0.6291699393336083
# 0.2291910208230336
# Mejor coeficiente previo: 0.22546945440230404
# Coeficiente actual: 0.2291910208230336
# alpha = 0.5800000000000002
# [fold 0]  coeficiente de correlación: 0.6067778857018563
# [fold 1]  coeficiente de correlación: 0.5320350692554161
# [fold 2]  coeficiente de correlación: 0.40441749879343986
# [fold 3]  coeficiente de correlación: -0.6119879571539015
# 0.23281062414920273
# Mejor coeficiente previo: 0.2291910208230336
# Coeficiente actual: 0.23281062414920273
# alpha = 0.6000000000000002
# [fold 0]  coeficiente de correlación: 0.604299391145824
# [fold 1]  coeficiente de correlación: 0.5314314234050226
# [fold 2]  coeficiente de correlación: 0.4045959558784417
# [fold 3]  coeficiente de correlación: -0.5950296115511859
# 0.23632428971952557
# Mejor coeficiente previo: 0.23281062414920273
# Coeficiente actual: 0.23632428971952557
# alpha = 0.6200000000000002
# [fold 0]  coeficiente de correlación: 0.601761097953428
# [fold 1]  coeficiente de correlación: 0.530823430765931
# [fold 2]  coeficiente de correlación: 0.40464300265701747
# [fold 3]  coeficiente de correlación: -0.5782950096966092
# 0.2397331304199418
# Mejor coeficiente previo: 0.23632428971952557
# Coeficiente actual: 0.2397331304199418
# alpha = 0.6400000000000002
# [fold 0]  coeficiente de correlación: 0.5991617855262132
# [fold 1]  coeficiente de correlación: 0.5303999561886084
# [fold 2]  coeficiente de correlación: 0.4045699278795236
# [fold 3]  coeficiente de correlación: -0.5617845083208179
# 0.24308679031838182
# Mejor coeficiente previo: 0.2397331304199418
# Coeficiente actual: 0.24308679031838182
# alpha = 0.6600000000000003
# [fold 0]  coeficiente de correlación: 0.5965029358088023
# [fold 1]  coeficiente de correlación: 0.5299639599606625
# [fold 2]  coeficiente de correlación: 0.40437109375529406
# [fold 3]  coeficiente de correlación: -0.545497184906196
# 0.2463352011546407
# Mejor coeficiente previo: 0.24308679031838182
# Coeficiente actual: 0.2463352011546407
# alpha = 0.6800000000000003
# [fold 0]  coeficiente de correlación: 0.5937838642473567
# [fold 1]  coeficiente de correlación: 0.529513972308753
# [fold 2]  coeficiente de correlación: 0.40404035624420814
# [fold 3]  coeficiente de correlación: -0.5294302330553873
# 0.24947698993623263
# Mejor coeficiente previo: 0.2463352011546407
# Coeficiente actual: 0.24947698993623263
# alpha = 0.7000000000000003
# [fold 0]  coeficiente de correlación: 0.5910051991100291
# [fold 1]  coeficiente de correlación: 0.5290484912641464
# [fold 2]  coeficiente de correlación: 0.4035901380659239
# [fold 3]  coeficiente de correlación: -0.5135875087310746
# 0.2525140799272562
# Mejor coeficiente previo: 0.24947698993623263
# Coeficiente actual: 0.2525140799272562
# alpha = 0.7200000000000003
# [fold 0]  coeficiente de correlación: 0.5881657903349375
# [fold 1]  coeficiente de correlación: 0.5285708196034846
# [fold 2]  coeficiente de correlación: 0.40301416199673934
# [fold 3]  coeficiente de correlación: -0.49797266754841907
# 0.2554445260966856
# Mejor coeficiente previo: 0.2525140799272562
# Coeficiente actual: 0.2554445260966856
# alpha = 0.7400000000000003
# [fold 0]  coeficiente de correlación: 0.5852662484819069
# [fold 1]  coeficiente de correlación: 0.5280792997007946
# [fold 2]  coeficiente de correlación: 0.4023124280366553
# [fold 3]  coeficiente de correlación: -0.4825825234248893
# 0.25826886319861686
# Mejor coeficiente previo: 0.2554445260966856
# Coeficiente actual: 0.25826886319861686
# alpha = 0.7600000000000003
# [fold 0]  coeficiente de correlación: 0.5823070210561215
# [fold 1]  coeficiente de correlación: 0.527573971866856
# [fold 2]  coeficiente de correlación: 0.4014783389846952
# [fold 3]  coeficiente de correlación: -0.4674164882110119
# 0.2609857109241652
# Mejor coeficiente previo: 0.25826886319861686
# Coeficiente actual: 0.2609857109241652
# alpha = 0.7800000000000004
# [fold 0]  coeficiente de correlación: 0.579287562054327
# [fold 1]  coeficiente de correlación: 0.527054831411734
# [fold 2]  coeficiente de correlación: 0.400525163400975
# [fold 3]  coeficiente de correlación: -0.45247456190679225
# 0.26359824874006094
# Mejor coeficiente previo: 0.2609857109241652
# Coeficiente actual: 0.26359824874006094
# alpha = 0.8000000000000004
# [fold 0]  coeficiente de correlación: 0.5762076561718292
# [fold 1]  coeficiente de correlación: 0.5265202874214807
# [fold 2]  coeficiente de correlación: 0.3994462270624065
# [fold 3]  coeficiente de correlación: -0.43775674451222324
# 0.2661043565358733
# Mejor coeficiente previo: 0.26359824874006094
# Coeficiente actual: 0.2661043565358733
# alpha = 0.8200000000000004
# [fold 0]  coeficiente de correlación: 0.5730679026950892
# [fold 1]  coeficiente de correlación: 0.5259735801016316
# [fold 2]  coeficiente de correlación: 0.39823415045285704
# [fold 3]  coeficiente de correlación: -0.42326303602730864
# 0.26850314930556735
# Mejor coeficiente previo: 0.2661043565358733
# Coeficiente actual: 0.26850314930556735
# alpha = 0.8400000000000004
# [fold 0]  coeficiente de correlación: 0.5698679869695582
# [fold 1]  coeficiente de correlación: 0.5254130841961401
# [fold 2]  coeficiente de correlación: 0.3969034681112739
# [fold 3]  coeficiente de correlación: -0.4089934364520489
# 0.2707977757062308
# Mejor coeficiente previo: 0.26850314930556735
# Coeficiente actual: 0.2707977757062308
# alpha = 0.8600000000000004
# [fold 0]  coeficiente de correlación: 0.5666077815865236
# [fold 1]  coeficiente de correlación: 0.5248387997050067
# [fold 2]  coeficiente de correlación: 0.39544702701767476
# [fold 3]  coeficiente de correlación: -0.3949479457864391
# 0.2729864156306915
# Mejor coeficiente previo: 0.2707977757062308
# Coeficiente actual: 0.2729864156306915
# alpha = 0.8800000000000004
# [fold 0]  coeficiente de correlación: 0.563287617997834
# [fold 1]  coeficiente de correlación: 0.524250726628231
# [fold 2]  coeficiente de correlación: 0.39385683359583457
# [fold 3]  coeficiente de correlación: -0.38112656403048706
# 0.2750671535478531
# Mejor coeficiente previo: 0.2729864156306915
# Coeficiente actual: 0.2750671535478531
# alpha = 0.9000000000000005
# [fold 0]  coeficiente de correlación: 0.5599073198881042
# [fold 1]  coeficiente de correlación: 0.523648884979522
# [fold 2]  coeficiente de correlación: 0.3921490221632958
# [fold 3]  coeficiente de correlación: -0.3675292911841883
# 0.2770439839616834
# Mejor coeficiente previo: 0.2750671535478531
# Coeficiente actual: 0.2770439839616834
# alpha = 0.9200000000000005
# [fold 0]  coeficiente de correlación: 0.5564668973859183
# [fold 1]  coeficiente de correlación: 0.5230332559015602
# [fold 2]  coeficiente de correlación: 0.39031545353505814
# [fold 3]  coeficiente de correlación: -0.3541561272475433
# 0.27891486989374836
# Mejor coeficiente previo: 0.2770439839616834
# Coeficiente actual: 0.27891486989374836
# alpha = 0.9400000000000005
# [fold 0]  coeficiente de correlación: 0.5529663528000834
# [fold 1]  coeficiente de correlación: 0.5224038303022808
# [fold 2]  coeficiente de correlación: 0.3883561277111217
# [fold 3]  coeficiente de correlación: -0.34100636263332373
# 0.28067998704504055
# Mejor coeficiente previo: 0.27891486989374836
# Coeficiente actual: 0.28067998704504055
# alpha = 0.9600000000000005
# [fold 0]  coeficiente de correlación: 0.5494056862004759
# [fold 1]  coeficiente de correlación: 0.5217591224645333
# [fold 2]  coeficiente de correlación: 0.3862637251727789
# [fold 3]  coeficiente de correlación: -0.3280794049866982
# 0.2823372822127725
# Mejor coeficiente previo: 0.28067998704504055
# Coeficiente actual: 0.2823372822127725
# alpha = 0.9800000000000005
# [fold 0]  coeficiente de correlación: 0.5457848975156524
# [fold 1]  coeficiente de correlación: 0.5211021477892464
# [fold 2]  coeficiente de correlación: 0.3840457625721104
# [fold 3]  coeficiente de correlación: -0.3153766228218182
# 0.28388904626379774
# Mejor coeficiente previo: 0.2823372822127725
# Coeficiente actual: 0.28388904626379774
# Mejor alpha en promedio 0.9800000000000005 con un coeficiente de correlacion promedio de : 0.28388904626379774
