# %% [markdown]
# # Introducción a Machine Learning
#
# Los procesos principales en Machine Learning  son los siguientes:
# 1. Recolección de datos
#
# 2. Procesamiento de datos
#
# 3. Identificación del modelo
#
# 4. Entrenamiento
#
# 5. Validación
#
# 6. Identificación de hiperparámetros
#
# 7. Predicción
#
#
#
# El proceso de aprendizaje es iterativo, por lo que es común que en cualquier paso nos podamos regresar a otro proceso, siempre con la finalidad de generar el mejor modelo.
#
# En esta práctica partiremos del punto 2, asumiendo que los datos ya están recolectados.

# %% [markdown]
# ## 2. procesamiento de datos

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

diabetes = datasets.load_diabetes()
X = diabetes.data
y = diabetes.target

print('Dimensiones en X = {}'.format(X.shape))
print('Dimensiones en y = {}'.format(y.shape))

# Samples total  442
# Dimensionality  10
# Features  real, -.2 < x < .2
# Targets integer 25 - 346
# Out:
# Dimensiones en X = (442, 10)
# Dimensiones en y = (442,)

# %% [markdown]
# ## 3. Identificación del modelo
#
# En este ejemplo se seleccionará  el modelo Lasso

# %%
from sklearn.linear_model import Lasso

linear_model = Lasso()

# %% [markdown]
# ## 4 y 5. Entrenamiento y Validación

# %%
from sklearn.model_selection import KFold

k_fold = KFold(n_splits=3)

for k, (train, test) in enumerate(k_fold.split(X, y)):
    # Se entrena con el conjunto de datos de entrenamiento
    linear_model.fit(X[train], y[train])
    # Se valida con el conjunto de datos de prueba
    print("[fold {}]  coeficiente de correlación: {}".format(k, linear_model.score(X[test], y[test])))
# Out:
# [fold 0]  coeficiente de correlación: 0.34542984833684853
# [fold 1]  coeficiente de correlación: 0.34712314449919834
# [fold 2]  coeficiente de correlación: 0.36884725706191346

# %% [markdown]
# ## 6. Identificación de hiperparámetros
#
# El modelo Lasso tiene un hiperparámetro que es alpha, por defecto tiene asignado el valor 1.0.
#
# Para identificar de qué forma se deberían modificar los hiperparámetros para aumentar el rendimiento, se debe conocer muy bien el algoritmo.
#
# Esta práctica tiene como objetivo el de conocer los procesos generales en el aprendizaje automático, así que la explicación del modelo está fuera de este ámbito. Sin embargo, se muestra la función objetivo para dar una intuición de cómo afecta éste hiperparámetro en el modelo.
#
# $$ Cost = (1 / (2 * num\_instancias)) * ||y - Xw||^2_2 + alpha * ||w||_1$$

# %%
linear_model2 = Lasso(alpha=0.1)
k_fold = KFold(n_splits=3)

for k, (train, test) in enumerate(k_fold.split(X, y)):
    # Se entrena con el conjunto de datos de entrenamiento
    linear_model2.fit(X[train], y[train])
    # Se valida con el conjunto de datos de prueba
    print("[fold {}]  coeficiente de correlación: {}".format(k, linear_model2.score(X[test], y[test])))
# Out:
# [fold 0]  coeficiente de correlación: 0.4553764654572192
# [fold 1]  coeficiente de correlación: 0.4970449650050526
# [fold 2]  coeficiente de correlación: 0.5075811884365067

# %% [markdown]
# # Ejercicio 1
#
# 1.1 Automatizar la búsqueda del mejor valor de alpha. Por ejemplo, realizar una búsqueda de 50 elementos en el rango [0,1]
#
# Emplear validación cruzada de 4 folds
#
# 1.2 Discutir cómo afecta el número de folds en el proceso de entrenamiento y validación; cuál valor es el adecuado.

# %%
#*EXTRA
def frange(start,stop,step):
    while(start<stop):
        yield start
        start = start+step

# %%
#Ejercicio 1.1 Busqueda del Alpha !!
n = 4
k_fold2 = KFold(n_splits=n)
AALPHA = 0
KALPHA = 0
IALPHA = 0
for i in frange(0.02,1,.02):
    AALPHA = 0
    print("alpha = {}".format(i))
    linear_model3 = Lasso(alpha = i)
    for k2, (train, test) in enumerate(k_fold2.split(X, y)):
        linear_model3.fit(X[train], y[train])
        # Se valida con el conjunto de datos de prueba
        print("[fold {}]  coeficiente de correlación: {}".format(k2, linear_model3.score(X[test], y[test])))
        AALPHA = AALPHA + (linear_model3.score(X[test],y[test]))    
    print(AALPHA/4)
    if(KALPHA == 0):
        KALPHA = (AALPHA/4)
    else:
        if(KALPHA < (AALPHA/4)):
            print("Mejor coeficiente previo: {} ".format(KALPHA))
            print("Coeficiente actual: {} ".format(AALPHA/4))
            IALPHA = i
            KALPHA = (AALPHA/4)
print("Mejor alpha en promedio {} con un coeficiente de correlacion de : {}".format(IALPHA,KALPHA))
# Out:
# alpha = 0.02
# [fold 0]  coeficiente de correlación: 0.3769289242773214
# [fold 1]  coeficiente de correlación: 0.491627611130961
# [fold 2]  coeficiente de correlación: 0.5190668895489858
# [fold 3]  coeficiente de correlación: 0.5520232571489545
# 0.48491167052655565
# alpha = 0.04
# [fold 0]  coeficiente de correlación: 0.3740694525340481
# [fold 1]  coeficiente de correlación: 0.49131929781241196
# [fold 2]  coeficiente de correlación: 0.5232127006233358
# [fold 3]  coeficiente de correlación: 0.5505138199236015
# 0.48477881772334935
# alpha = 0.06
# [fold 0]  coeficiente de correlación: 0.3712448906760034
# [fold 1]  coeficiente de correlación: 0.4899057395240403
# [fold 2]  coeficiente de correlación: 0.526067494387482
# [fold 3]  coeficiente de correlación: 0.5492321090698324
# 0.4841125584143396
# alpha = 0.08
# [fold 0]  coeficiente de correlación: 0.3681075893657215
# [fold 1]  coeficiente de correlación: 0.4879878655074767
# [fold 2]  coeficiente de correlación: 0.5272153255204882
# [fold 3]  coeficiente de correlación: 0.5463826281783588
# 0.4824233521430113
# alpha = 0.1
# [fold 0]  coeficiente de correlación: 0.3644958015494224
# [fold 1]  coeficiente de correlación: 0.4855648325537299
# [fold 2]  coeficiente de correlación: 0.5272174060509351
# [fold 3]  coeficiente de correlación: 0.5438047541733583
# 0.48027069858186144
# alpha = 0.12000000000000001
# [fold 0]  coeficiente de correlación: 0.3606869258514913
# [fold 1]  coeficiente de correlación: 0.4824232867942369
# [fold 2]  coeficiente de correlación: 0.5268683850546567
# [fold 3]  coeficiente de correlación: 0.5413152987795159
# 0.47782347411997517
# alpha = 0.14
# [fold 0]  coeficiente de correlación: 0.3592612132086468
# [fold 1]  coeficiente de correlación: 0.4794689685503007
# [fold 2]  coeficiente de correlación: 0.5261707808886207
# [fold 3]  coeficiente de correlación: 0.5382783545011129
# 0.47579482928717026
# alpha = 0.16
# [fold 0]  coeficiente de correlación: 0.3575702534500782
# [fold 1]  coeficiente de correlación: 0.47699344472200234
# [fold 2]  coeficiente de correlación: 0.525123914927382
# [fold 3]  coeficiente de correlación: 0.5346945177868266
# 0.4735955327215723
# alpha = 0.18
# [fold 0]  coeficiente de correlación: 0.35561325132640675
# [fold 1]  coeficiente de correlación: 0.47448502054195
# [fold 2]  coeficiente de correlación: 0.5237268201148251
# [fold 3]  coeficiente de correlación: 0.5309882216829112
# 0.47120332841652324
# alpha = 0.19999999999999998
# [fold 0]  coeficiente de correlación: 0.35339019816200623
# [fold 1]  coeficiente de correlación: 0.4716965335399377
# [fold 2]  coeficiente de correlación: 0.5219817457424014
# [fold 3]  coeficiente de correlación: 0.5274493289383079
# 0.46862945159566327
# alpha = 0.21999999999999997
# [fold 0]  coeficiente de correlación: 0.35090106266498045
# [fold 1]  coeficiente de correlación: 0.46862731755943043
# [fold 2]  coeficiente de correlación: 0.5198262222889101
# [fold 3]  coeficiente de correlación: 0.523591511802725
# 0.4657365285790115
# alpha = 0.23999999999999996
# [fold 0]  coeficiente de correlación: 0.3481458782511986
# [fold 1]  coeficiente de correlación: 0.4652830353790172
# [fold 2]  coeficiente de correlación: 0.5172497747463913
# [fold 3]  coeficiente de correlación: 0.519408633113922
# 0.4625218303726323
# alpha = 0.25999999999999995
# [fold 0]  coeficiente de correlación: 0.34620274381520455
# [fold 1]  coeficiente de correlación: 0.4616609203265224
# [fold 2]  coeficiente de correlación: 0.5143512846845586
# [fold 3]  coeficiente de correlación: 0.5149059217963102
# 0.45928021765564897
# alpha = 0.27999999999999997
# [fold 0]  coeficiente de correlación: 0.34698199904970795
# [fold 1]  coeficiente de correlación: 0.45776097240194585
# [fold 2]  coeficiente de correlación: 0.5111326279697566
# [fold 3]  coeficiente de correlación: 0.5101000541206504
# 0.4564939133855152
# alpha = 0.3
# [fold 0]  coeficiente de correlación: 0.3476139608027433
# [fold 1]  coeficiente de correlación: 0.4541665492799456
# [fold 2]  coeficiente de correlación: 0.5075900483533455
# [fold 3]  coeficiente de correlación: 0.5072736605829902
# 0.45416105475475615
# alpha = 0.32
# [fold 0]  coeficiente de correlación: 0.34810154900163714
# [fold 1]  coeficiente de correlación: 0.4521184480882562
# [fold 2]  coeficiente de correlación: 0.5037253909609968
# [fold 3]  coeficiente de correlación: 0.5047504042053929
# 0.45217394806407074
# alpha = 0.34
# [fold 0]  coeficiente de correlación: 0.3484432323166544
# [fold 1]  coeficiente de correlación: 0.44996051082001115
# [fold 2]  coeficiente de correlación: 0.4995542879865912
# [fold 3]  coeficiente de correlación: 0.5021014473773671
# 0.45001486962515597
# alpha = 0.36000000000000004
# [fold 0]  coeficiente de correlación: 0.3486390083081835
# [fold 1]  coeficiente de correlación: 0.44769140559269605
# [fold 2]  coeficiente de correlación: 0.4963784688397441
# [fold 3]  coeficiente de correlación: 0.49932721939564406
# 0.44800902553406696
# alpha = 0.38000000000000006
# [fold 0]  coeficiente de correlación: 0.3486888766685128
# [fold 1]  coeficiente de correlación: 0.44531110919322353
# [fold 2]  coeficiente de correlación: 0.4930830023010857
# [fold 3]  coeficiente de correlación: 0.4964275963119755
# 0.4458776461186994
# alpha = 0.4000000000000001
# [fold 0]  coeficiente de correlación: 0.34859283739764213
# [fold 1]  coeficiente de correlación: 0.44281962162159433
# [fold 2]  coeficiente de correlación: 0.4896684136446123
# [fold 3]  coeficiente de correlación: 0.4934024583538937
# 0.4436208327544356
# alpha = 0.4200000000000001
# [fold 0]  coeficiente de correlación: 0.34835089049557133
# [fold 1]  coeficiente de correlación: 0.440216942877808
# [fold 2]  coeficiente de correlación: 0.48613461043294953
# [fold 3]  coeficiente de correlación: 0.49025176480033744
# 0.4412385521516666
# alpha = 0.4400000000000001
# [fold 0]  coeficiente de correlación: 0.3479630359623008
# [fold 1]  coeficiente de correlación: 0.43750307296186464
# [fold 2]  coeficiente de correlación: 0.4824815556761676
# [fold 3]  coeficiente de correlación: 0.48697551440088044
# 0.43873079475030335
# alpha = 0.46000000000000013
# [fold 0]  coeficiente de correlación: 0.3474293402626649
# [fold 1]  coeficiente de correlación: 0.4346780118737641
# [fold 2]  coeficiente de correlación: 0.4787092493742667
# [fold 3]  coeficiente de correlación: 0.4835737071555225
# 0.4360975771665545
# alpha = 0.48000000000000015
# [fold 0]  coeficiente de correlación: 0.34674979804104855
# [fold 1]  coeficiente de correlación: 0.4317417596135065
# [fold 2]  coeficiente de correlación: 0.47481769152724645
# [fold 3]  coeficiente de correlación: 0.480046343064264
# 0.4333388980615164
# alpha = 0.5000000000000001
# [fold 0]  coeficiente de correlación: 0.34587155086910726
# [fold 1]  coeficiente de correlación: 0.42869431618109205
# [fold 2]  coeficiente de correlación: 0.4708068821351068
# [fold 3]  coeficiente de correlación: 0.47639342212710456
# 0.43044154282810265
# alpha = 0.5200000000000001
# [fold 0]  coeficiente de correlación: 0.3445492882218246
# [fold 1]  coeficiente de correlación: 0.4255356815765203
# [fold 2]  coeficiente de correlación: 0.4666768211978481
# [fold 3]  coeficiente de correlación: 0.47261494434404455
# 0.4273441838350594
# alpha = 0.5400000000000001
# [fold 0]  coeficiente de correlación: 0.34308461284265646
# [fold 1]  coeficiente de correlación: 0.4222658557997917
# [fold 2]  coeficiente de correlación: 0.4624275087154703
# [fold 3]  coeficiente de correlación: 0.4687109097150834
# 0.4241222217682505
# alpha = 0.5600000000000002
# [fold 0]  coeficiente de correlación: 0.3414776076742573
# [fold 1]  coeficiente de correlación: 0.41888483885090627
# [fold 2]  coeficiente de correlación: 0.45805894468797326
# [fold 3]  coeficiente de correlación: 0.4646813182402218
# 0.42077567736333965
# alpha = 0.5800000000000002
# [fold 0]  coeficiente de correlación: 0.33972827271662676
# [fold 1]  coeficiente de correlación: 0.4153926307298635
# [fold 2]  coeficiente de correlación: 0.453571129115357
# [fold 3]  coeficiente de correlación: 0.46052616991945927
# 0.4173045506203267
# alpha = 0.6000000000000002
# [fold 0]  coeficiente de correlación: 0.33783660796976533
# [fold 1]  coeficiente de correlación: 0.41178923143666374
# [fold 2]  coeficiente de correlación: 0.4489640553746744
# [fold 3]  coeficiente de correlación: 0.4562454647527961
# 0.41370883988347484
# alpha = 0.6200000000000002
# [fold 0]  coeficiente de correlación: 0.33580261343367257
# [fold 1]  coeficiente de correlación: 0.4080746409713071
# [fold 2]  coeficiente de correlación: 0.4442377165066996
# [fold 3]  coeficiente de correlación: 0.4518392027402321
# 0.4099885434129778
# alpha = 0.6400000000000002
# [fold 0]  coeficiente de correlación: 0.333626289108349
# [fold 1]  coeficiente de correlación: 0.40424885933379306
# [fold 2]  coeficiente de correlación: 0.4399506829387572
# [fold 3]  coeficiente de correlación: 0.44730738388176705
# 0.4062833038156666
# alpha = 0.6600000000000003
# [fold 0]  coeficiente de correlación: 0.3313076349937938
# [fold 1]  coeficiente de correlación: 0.40031188652412236
# [fold 2]  coeficiente de correlación: 0.43587772226993204
# [fold 3]  coeficiente de correlación: 0.4426500081774016
# 0.40253681299131244
# alpha = 0.6800000000000003
# [fold 0]  coeficiente de correlación: 0.3288466510900079
# [fold 1]  coeficiente de correlación: 0.3962637225422943
# [fold 2]  coeficiente de correlación: 0.4317044125682865
# [fold 3]  coeficiente de correlación: 0.4378670756271351
# 0.39867046545693097
# alpha = 0.7000000000000003
# [fold 0]  coeficiente de correlación: 0.3262433373969905
# [fold 1]  coeficiente de correlación: 0.39246221891249233
# [fold 2]  coeficiente de correlación: 0.4274352253599109
# [fold 3]  coeficiente de correlación: 0.43295855500720576
# 0.3947748341691499
# alpha = 0.7200000000000003
# [fold 0]  coeficiente de correlación: 0.32349769391474203
# [fold 1]  coeficiente de correlación: 0.3888611374141713
# [fold 2]  coeficiente de correlación: 0.42306775117296913
# [fold 3]  coeficiente de correlación: 0.4280515081405349
# 0.3908695226606044
# alpha = 0.7400000000000003
# [fold 0]  coeficiente de correlación: 0.32060972064326276
# [fold 1]  coeficiente de correlación: 0.38516317301079817
# [fold 2]  coeficiente de correlación: 0.41860212099274385
# [fold 3]  coeficiente de correlación: 0.4235087128584844
# 0.3869709318763223
# alpha = 0.7600000000000003
# [fold 0]  coeficiente de correlación: 0.3175794121869995
# [fold 1]  coeficiente de correlación: 0.38136703477488065
# [fold 2]  coeficiente de correlación: 0.4140383356141854
# [fold 3]  coeficiente de correlación: 0.41885446163855444
# 0.38295981105365495
# alpha = 0.7800000000000004
# [fold 0]  coeficiente de correlación: 0.3144067705068079
# [fold 1]  coeficiente de correlación: 0.37747280301482455
# [fold 2]  coeficiente de correlación: 0.4093763964475514
# [fold 3]  coeficiente de correlación: 0.41408881309168405
# 0.37883619576521693
# alpha = 0.8000000000000004
# [fold 0]  coeficiente de correlación: 0.3110920949764988
# [fold 1]  coeficiente de correlación: 0.37348056195665824
# [fold 2]  coeficiente de correlación: 0.4046163581810502
# [fold 3]  coeficiente de correlación: 0.4092116851191759
# 0.37460017505834575
# alpha = 0.8200000000000004
# [fold 0]  coeficiente de correlación: 0.3077113797946812
# [fold 1]  coeficiente de correlación: 0.36939023063104404
# [fold 2]  coeficiente de correlación: 0.3997581687404614
# [fold 3]  coeficiente de correlación: 0.40422307772103006
# 0.3702707142218042
# alpha = 0.8400000000000004
# [fold 0]  coeficiente de correlación: 0.3046475232937993
# [fold 1]  coeficiente de correlación: 0.3652018090379813
# [fold 2]  coeficiente de correlación: 0.3948018281257842
# [fold 3]  coeficiente de correlación: 0.3991230035281656
# 0.3659435409964326
# alpha = 0.8600000000000004
# [fold 0]  coeficiente de correlación: 0.3014737937478621
# [fold 1]  coeficiente de correlación: 0.3609152971774704
# [fold 2]  coeficiente de correlación: 0.3897473363370195
# [fold 3]  coeficiente de correlación: 0.39468610539409393
# 0.36170563316411153
# alpha = 0.8800000000000004
# [fold 0]  coeficiente de correlación: 0.2981904857584198
# [fold 1]  coeficiente de correlación: 0.3565306950495113
# [fold 2]  coeficiente de correlación: 0.3845946933741668
# [fold 3]  coeficiente de correlación: 0.39061614973429387
# 0.35748300597909793
# alpha = 0.9000000000000005
# [fold 0]  coeficiente de correlación: 0.2947976007228278
# [fold 1]  coeficiente de correlación: 0.35204800265410374
# [fold 2]  coeficiente de correlación: 0.37934389923722656
# [fold 3]  coeficiente de correlación: 0.38645130487850604
# 0.35316020187316605
# alpha = 0.9200000000000005
# [fold 0]  coeficiente de correlación: 0.29129516536781175
# [fold 1]  coeficiente de correlación: 0.34746721999124786
# [fold 2]  coeficiente de correlación: 0.3739949887795133
# [fold 3]  coeficiente de correlación: 0.3821909759595369
# 0.3487370875245275
# alpha = 0.9400000000000005
# [fold 0]  coeficiente de correlación: 0.28768314893785163
# [fold 1]  coeficiente de correlación: 0.34278835603609425
# [fold 2]  coeficiente de correlación: 0.36927114551598517
# [fold 3]  coeficiente de correlación: 0.3778357886139615
# 0.34439460977597314
# alpha = 0.9600000000000005
# [fold 0]  coeficiente de correlación: 0.28396155143294743
# [fold 1]  coeficiente de correlación: 0.33801141484965636
# [fold 2]  coeficiente de correlación: 0.36469072820128945
# [fold 3]  coeficiente de correlación: 0.3733841376495943
# 0.3400119580333719
# alpha = 0.9800000000000005
# [fold 0]  coeficiente de correlación: 0.2801303728530985
# [fold 1]  coeficiente de correlación: 0.3331363843209304
# [fold 2]  coeficiente de correlación: 0.3600225995190942
# [fold 3]  coeficiente de correlación: 0.3688403180385744
# 0.3355324186829244
# Mejor alpha en promedio 0 con un coeficiente de correlacion de : 0.48491167052655565

# %% [markdown]
# # Ejercicio 2
#
# Programar los siguientes errores: $sse$, $mse$, $rmse$
#
# Agregar las métricas en el proceso de validación del modelo

# %%
def SSEf(Yr,Yi):
    return (Yr-Yi)**2
    
def SSE(Yr,Yi):
    Sum = 0
    for i in range(0,len(Yr)):
        Sum = Sum + SSEf(Yr[i],Yi[i])    
        

def MSE(Yr,Yi):
    n = len(Yr)
    Y = SSE(Yr,Yi)
    return (Y/n)

def RMSE(Yr,Yi):
    return MSE(Yr,Yi)**.5

# %% [markdown]
# # Ejercicio 3
# Graficar los valores obtenidos por el modelo, con el mejor hiper-parámetro, y los valores reales de cada uno de los folds.

# %% [markdown]
# # Ejercicio 4
#
# Replicar los ejercicios 1, 2 y 3 con el dataset boston.
#
# Ejemplo:

# %%
from sklearn.datasets import load_boston
boston = load_boston()
Z = boston.data
a = boston.target
Z
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
n = 4 
k_fold3 = KFold(n_splits=n)
AALPHA = 0
KALPHA = 0
IALPHA = 0
for i in frange(0.02,1,.02):
    AALPHA = 0
    print("alpha = {}".format(i))
    linear_model4 = Lasso(alpha = i)
    for k2, (train, test) in enumerate(k_fold3.split(Z, a)):
        linear_model4.fit(Z[train], a[train])
        # Se valida con el conjunto de datos de prueba
        print("[fold {}]  coeficiente de correlación: {}".format(k2, linear_model4.score(Z[test], a[test])))
        AALPHA = AALPHA + (linear_model4.score(Z[test],a[test]))    
    print(AALPHA/4)
    if(KALPHA == 0):
        KALPHA = (AALPHA/4)
    else:
        if(KALPHA < (AALPHA/4)):
            print("Mejor coeficiente previo: {} ".format(KALPHA))
            print("Coeficiente actual: {} ".format(AALPHA/4))
            IALPHA = i
            KALPHA = (AALPHA/4)
print("Mejor alpha en promedio {} con un coeficiente de correlacion promedio de : {}".format(IALPHA,KALPHA))
# Out:
# alpha = 0.02
# [fold 0]  coeficiente de correlación: 0.6213988695064239
# [fold 1]  coeficiente de correlación: 0.6064232922012476
# [fold 2]  coeficiente de correlación: 0.35765810694009004
# [fold 3]  coeficiente de correlación: -0.9966977838336595
# 0.14719562120352547
# alpha = 0.04
# [fold 0]  coeficiente de correlación: 0.6367945805750947
# [fold 1]  coeficiente de correlación: 0.5860427085338555
# [fold 2]  coeficiente de correlación: 0.3550045425554019
# [fold 3]  coeficiente de correlación: -0.8966285273516204
# 0.170303326078183
# Mejor coeficiente previo: 0.14719562120352547
# Coeficiente actual: 0.170303326078183
# alpha = 0.06
# [fold 0]  coeficiente de correlación: 0.6482717484265268
# [fold 1]  coeficiente de correlación: 0.5908239413244165
# [fold 2]  coeficiente de correlación: 0.3559220347040888
# [fold 3]  coeficiente de correlación: -0.8848802365116815
# 0.17753437198583766
# Mejor coeficiente previo: 0.170303326078183
# Coeficiente actual: 0.17753437198583766
# alpha = 0.08
# [fold 0]  coeficiente de correlación: 0.6547833728640053
# [fold 1]  coeficiente de correlación: 0.5953513334718729
# [fold 2]  coeficiente de correlación: 0.35939461933885175
# [fold 3]  coeficiente de correlación: -0.8804069950222635
# 0.18228058266311664
# Mejor coeficiente previo: 0.17753437198583766
# Coeficiente actual: 0.18228058266311664
# alpha = 0.1
# [fold 0]  coeficiente de correlación: 0.6534236080400263
# [fold 1]  coeficiente de correlación: 0.5989522436842124
# [fold 2]  coeficiente de correlación: 0.36273760570594216
# [fold 3]  coeficiente de correlación: -0.8570804805102382
# 0.18950824422998566
# Mejor coeficiente previo: 0.18228058266311664
# Coeficiente actual: 0.18950824422998566
# alpha = 0.12000000000000001
# [fold 0]  coeficiente de correlación: 0.6518379433628847
# [fold 1]  coeficiente de correlación: 0.6016260884501183
# [fold 2]  coeficiente de correlación: 0.3659538568002787
# [fold 3]  coeficiente de correlación: -0.8369212606702598
# 0.19562415698575547
# Mejor coeficiente previo: 0.18950824422998566
# Coeficiente actual: 0.19562415698575547
# alpha = 0.14
# [fold 0]  coeficiente de correlación: 0.6500268132634917
# [fold 1]  coeficiente de correlación: 0.6033740077709455
# [fold 2]  coeficiente de correlación: 0.36904006752085866
# [fold 3]  coeficiente de correlación: -0.8187430300374567
# 0.2009244646294598
# Mejor coeficiente previo: 0.19562415698575547
# Coeficiente actual: 0.2009244646294598
# alpha = 0.16
# [fold 0]  coeficiente de correlación: 0.6479898566192557
# [fold 1]  coeficiente de correlación: 0.6041954273786494
# [fold 2]  coeficiente de correlación: 0.3719933810333532
# [fold 3]  coeficiente de correlación: -0.8033161875472588
# 0.20521561937099986
# Mejor coeficiente previo: 0.2009244646294598
# Coeficiente actual: 0.20521561937099986
# alpha = 0.18
# [fold 0]  coeficiente de correlación: 0.6457272434900732
# [fold 1]  coeficiente de correlación: 0.6040895967860942
# [fold 2]  coeficiente de correlación: 0.3748205688529032
# [fold 3]  coeficiente de correlación: -0.7906202968938987
# 0.20850427805879296
# Mejor coeficiente previo: 0.20521561937099986
# Coeficiente actual: 0.20850427805879296
# alpha = 0.19999999999999998
# [fold 0]  coeficiente de correlación: 0.643774510802972
# [fold 1]  coeficiente de correlación: 0.603058038963104
# [fold 2]  coeficiente de correlación: 0.3775179543455273
# [fold 3]  coeficiente de correlación: -0.7806455869259581
# 0.2109262292964113
# Mejor coeficiente previo: 0.20850427805879296
# Coeficiente actual: 0.2109262292964113
# alpha = 0.21999999999999997
# [fold 0]  coeficiente de correlación: 0.6424300508498408
# [fold 1]  coeficiente de correlación: 0.6010991554378801
# [fold 2]  coeficiente de correlación: 0.38008214638641014
# [fold 3]  coeficiente de correlación: -0.7733767420458777
# 0.2125586526570633
# Mejor coeficiente previo: 0.2109262292964113
# Coeficiente actual: 0.2125586526570633
# alpha = 0.23999999999999996
# [fold 0]  coeficiente de correlación: 0.6410163465264317
# [fold 1]  coeficiente de correlación: 0.5975392337617416
# [fold 2]  coeficiente de correlación: 0.38252013746316144
# [fold 3]  coeficiente de correlación: -0.768835958013238
# 0.2130599399345242
# Mejor coeficiente previo: 0.2125586526570633
# Coeficiente actual: 0.2130599399345242
# alpha = 0.25999999999999995
# [fold 0]  coeficiente de correlación: 0.6395336470704852
# [fold 1]  coeficiente de correlación: 0.5934408570667067
# [fold 2]  coeficiente de correlación: 0.38482804458547804
# [fold 3]  coeficiente de correlación: -0.7670091495838769
# 0.21269834978469832
# alpha = 0.27999999999999997
# [fold 0]  coeficiente de correlación: 0.637981609156379
# [fold 1]  coeficiente de correlación: 0.589302537285521
# [fold 2]  coeficiente de correlación: 0.3870023822729544
# [fold 3]  coeficiente de correlación: -0.7680001568178261
# 0.2115715929742571
# alpha = 0.3
# [fold 0]  coeficiente de correlación: 0.636360393361469
# [fold 1]  coeficiente de correlación: 0.585123202848528
# [fold 2]  coeficiente de correlación: 0.38905064444361204
# [fold 3]  coeficiente de correlación: -0.7739989840541457
# 0.20913381414986582
# alpha = 0.32
# [fold 0]  coeficiente de correlación: 0.6346703233893545
# [fold 1]  coeficiente de correlación: 0.5809016678134955
# [fold 2]  coeficiente de correlación: 0.3909683606923626
# [fold 3]  coeficiente de correlación: -0.7823732092164841
# 0.20604178566968212
# alpha = 0.34
# [fold 0]  coeficiente de correlación: 0.632910777961506
# [fold 1]  coeficiente de correlación: 0.5766402719521186
# [fold 2]  coeficiente de correlación: 0.39275611387987563
# [fold 3]  coeficiente de correlación: -0.791666628497183
# 0.20266013382407932
# alpha = 0.36000000000000004
# [fold 0]  coeficiente de correlación: 0.631081989301276
# [fold 1]  coeficiente de correlación: 0.5723378649052406
# [fold 2]  coeficiente de correlación: 0.39441407379238236
# [fold 3]  coeficiente de correlación: -0.8032035786472576
# 0.1986575873379104
# alpha = 0.38000000000000006
# [fold 0]  coeficiente de correlación: 0.6291844180819807
# [fold 1]  coeficiente de correlación: 0.5679944466728621
# [fold 2]  coeficiente de correlación: 0.39594218079275784
# [fold 3]  coeficiente de correlación: -0.7939202562863956
# 0.1998001973153013
# alpha = 0.4000000000000001
# [fold 0]  coeficiente de correlación: 0.6271360806894027
# [fold 1]  coeficiente de correlación: 0.5636086335716332
# [fold 2]  coeficiente de correlación: 0.3973405539813809
# [fold 3]  coeficiente de correlación: -0.7747137374541229
# 0.20334288269707346
# alpha = 0.4200000000000001
# [fold 0]  coeficiente de correlación: 0.625032025718477
# [fold 1]  coeficiente de correlación: 0.5591832926581644
# [fold 2]  coeficiente de correlación: 0.3986092389773827
# [fold 3]  coeficiente de correlación: -0.7557296746492181
# 0.20677372067620153
# alpha = 0.4400000000000001
# [fold 0]  coeficiente de correlación: 0.6228761202738986
# [fold 1]  coeficiente de correlación: 0.5547169443329019
# [fold 2]  coeficiente de correlación: 0.3997479942602257
# [fold 3]  coeficiente de correlación: -0.7369795620961087
# 0.21009037419272938
# alpha = 0.46000000000000013
# [fold 0]  coeficiente de correlación: 0.6206683847320178
# [fold 1]  coeficiente de correlación: 0.5502095869823229
# [fold 2]  coeficiente de correlación: 0.4007567967794954
# [fold 3]  coeficiente de correlación: -0.7184538575642616
# 0.21329522773239362
# Mejor coeficiente previo: 0.2130599399345242
# Coeficiente actual: 0.21329522773239362
# alpha = 0.48000000000000015
# [fold 0]  coeficiente de correlación: 0.6184193001844025
# [fold 1]  coeficiente de correlación: 0.5456596451978788
# [fold 2]  coeficiente de correlación: 0.4016475474907718
# [fold 3]  coeficiente de correlación: -0.7001518004221725
# 0.21639367311272018
# Mejor coeficiente previo: 0.21329522773239362
# Coeficiente actual: 0.21639367311272018
# alpha = 0.5000000000000001
# [fold 0]  coeficiente de correlación: 0.6161976779073557
# [fold 1]  coeficiente de correlación: 0.5410703308187157
# [fold 2]  coeficiente de correlación: 0.4024514815888209
# [fold 3]  coeficiente de correlación: -0.6820699770500547
# 0.2194123783162094
# Mejor coeficiente previo: 0.21639367311272018
# Coeficiente actual: 0.2194123783162094
# alpha = 0.5200000000000001
# [fold 0]  coeficiente de correlación: 0.6139150917908169
# [fold 1]  coeficiente de correlación: 0.5364385234948066
# [fold 2]  coeficiente de correlación: 0.40313288287369003
# [fold 3]  coeficiente de correlación: -0.6642070752656688
# 0.22231985572341117
# Mejor coeficiente previo: 0.2194123783162094
# Coeficiente actual: 0.22231985572341117
# alpha = 0.5400000000000001
# [fold 0]  coeficiente de correlación: 0.6115713885562009
# [fold 1]  coeficiente de correlación: 0.5331991258978623
# [fold 2]  coeficiente de correlación: 0.40368330670676045
# [fold 3]  coeficiente de correlación: -0.6465760035516068
# 0.2254694544023042
# Mejor coeficiente previo: 0.22231985572341117
# Coeficiente actual: 0.2254694544023042
# alpha = 0.5600000000000002
# [fold 0]  coeficiente de correlación: 0.6091959585966242
# [fold 1]  coeficiente de correlación: 0.5326247835178552
# [fold 2]  coeficiente de correlación: 0.40411328051126355
# [fold 3]  coeficiente de correlación: -0.6291699393336061
# 0.22919102082303422
# Mejor coeficiente previo: 0.2254694544023042
# Coeficiente actual: 0.22919102082303422
# alpha = 0.5800000000000002
# [fold 0]  coeficiente de correlación: 0.6067778857018566
# [fold 1]  coeficiente de correlación: 0.5320350692554162
# [fold 2]  coeficiente de correlación: 0.4044174987934397
# [fold 3]  coeficiente de correlación: -0.6119879571539
# 0.23281062414920317
# Mejor coeficiente previo: 0.22919102082303422
# Coeficiente actual: 0.23281062414920317
# alpha = 0.6000000000000002
# [fold 0]  coeficiente de correlación: 0.6042993911458239
# [fold 1]  coeficiente de correlación: 0.5314314234050226
# [fold 2]  coeficiente de correlación: 0.40459595587844177
# [fold 3]  coeficiente de correlación: -0.595029611551184
# 0.23632428971952607
# Mejor coeficiente previo: 0.23281062414920317
# Coeficiente actual: 0.23632428971952607
# alpha = 0.6200000000000002
# [fold 0]  coeficiente de correlación: 0.6017610979534278
# [fold 1]  coeficiente de correlación: 0.5308234307659307
# [fold 2]  coeficiente de correlación: 0.4046430026570176
# [fold 3]  coeficiente de correlación: -0.5782950096966075
# 0.23973313041994215
# Mejor coeficiente previo: 0.23632428971952607
# Coeficiente actual: 0.23973313041994215
# alpha = 0.6400000000000002
# [fold 0]  coeficiente de correlación: 0.5991617855262135
# [fold 1]  coeficiente de correlación: 0.5303999561886084
# [fold 2]  coeficiente de correlación: 0.4045699278795236
# [fold 3]  coeficiente de correlación: -0.5617845083208182
# 0.24308679031838182
# Mejor coeficiente previo: 0.23973313041994215
# Coeficiente actual: 0.24308679031838182
# alpha = 0.6600000000000003
# [fold 0]  coeficiente de correlación: 0.5965029358088021
# [fold 1]  coeficiente de correlación: 0.529963959960662
# [fold 2]  coeficiente de correlación: 0.4043710937552939
# [fold 3]  coeficiente de correlación: -0.5454971849061949
# 0.2463352011546408
# Mejor coeficiente previo: 0.24308679031838182
# Coeficiente actual: 0.2463352011546408
# alpha = 0.6800000000000003
# [fold 0]  coeficiente de correlación: 0.5937838642473572
# [fold 1]  coeficiente de correlación: 0.5295139723087529
# [fold 2]  coeficiente de correlación: 0.40404035624420814
# [fold 3]  coeficiente de correlación: -0.5294302330553866
# 0.2494769899362329
# Mejor coeficiente previo: 0.2463352011546408
# Coeficiente actual: 0.2494769899362329
# alpha = 0.7000000000000003
# [fold 0]  coeficiente de correlación: 0.5910051991100291
# [fold 1]  coeficiente de correlación: 0.5290484912641467
# [fold 2]  coeficiente de correlación: 0.40359013806592375
# [fold 3]  coeficiente de correlación: -0.5135875087310742
# 0.25251407992725633
# Mejor coeficiente previo: 0.2494769899362329
# Coeficiente actual: 0.25251407992725633
# alpha = 0.7200000000000003
# [fold 0]  coeficiente de correlación: 0.5881657903349377
# [fold 1]  coeficiente de correlación: 0.5285708196034846
# [fold 2]  coeficiente de correlación: 0.40301416199673956
# [fold 3]  coeficiente de correlación: -0.4979726675484182
# 0.25544452609668594
# Mejor coeficiente previo: 0.25251407992725633
# Coeficiente actual: 0.25544452609668594
# alpha = 0.7400000000000003
# [fold 0]  coeficiente de correlación: 0.5852662484819069
# [fold 1]  coeficiente de correlación: 0.5280792997007946
# [fold 2]  coeficiente de correlación: 0.4023124280366553
# [fold 3]  coeficiente de correlación: -0.4825825234248895
# 0.2582688631986168
# Mejor coeficiente previo: 0.25544452609668594
# Coeficiente actual: 0.2582688631986168
# alpha = 0.7600000000000003
# [fold 0]  coeficiente de correlación: 0.5823070210561221
# [fold 1]  coeficiente de correlación: 0.527573971866856
# [fold 2]  coeficiente de correlación: 0.4014783389846949
# [fold 3]  coeficiente de correlación: -0.46741648821101306
# 0.260985710924165
# Mejor coeficiente previo: 0.2582688631986168
# Coeficiente actual: 0.260985710924165
# alpha = 0.7800000000000004
# [fold 0]  coeficiente de correlación: 0.5792875620543267
# [fold 1]  coeficiente de correlación: 0.5270548314117338
# [fold 2]  coeficiente de correlación: 0.4005251634009751
# [fold 3]  coeficiente de correlación: -0.45247456190679025
# 0.2635982487400614
# Mejor coeficiente previo: 0.260985710924165
# Coeficiente actual: 0.2635982487400614
# alpha = 0.8000000000000004
# [fold 0]  coeficiente de correlación: 0.5762076561718292
# [fold 1]  coeficiente de correlación: 0.5265202874214805
# [fold 2]  coeficiente de correlación: 0.3994462270624064
# [fold 3]  coeficiente de correlación: -0.43775674451222146
# 0.26610435653587367
# Mejor coeficiente previo: 0.2635982487400614
# Coeficiente actual: 0.26610435653587367
# alpha = 0.8200000000000004
# [fold 0]  coeficiente de correlación: 0.573067902695089
# [fold 1]  coeficiente de correlación: 0.5259735801016316
# [fold 2]  coeficiente de correlación: 0.39823415045285704
# [fold 3]  coeficiente de correlación: -0.4232630360273071
# 0.2685031493055676
# Mejor coeficiente previo: 0.26610435653587367
# Coeficiente actual: 0.2685031493055676
# alpha = 0.8400000000000004
# [fold 0]  coeficiente de correlación: 0.569867986969557
# [fold 1]  coeficiente de correlación: 0.5254130841961404
# [fold 2]  coeficiente de correlación: 0.3969034681112739
# [fold 3]  coeficiente de correlación: -0.4089934364520482
# 0.27079777570623076
# Mejor coeficiente previo: 0.2685031493055676
# Coeficiente actual: 0.27079777570623076
# alpha = 0.8600000000000004
# [fold 0]  coeficiente de correlación: 0.5666077815865236
# [fold 1]  coeficiente de correlación: 0.5248387997050066
# [fold 2]  coeficiente de correlación: 0.39544702701767476
# [fold 3]  coeficiente de correlación: -0.3949479457864391
# 0.2729864156306915
# Mejor coeficiente previo: 0.27079777570623076
# Coeficiente actual: 0.2729864156306915
# alpha = 0.8800000000000004
# [fold 0]  coeficiente de correlación: 0.5632876179978339
# [fold 1]  coeficiente de correlación: 0.524250726628231
# [fold 2]  coeficiente de correlación: 0.39385683359583457
# [fold 3]  coeficiente de correlación: -0.38112656403048706
# 0.2750671535478531
# Mejor coeficiente previo: 0.2729864156306915
# Coeficiente actual: 0.2750671535478531
# alpha = 0.9000000000000005
# [fold 0]  coeficiente de correlación: 0.5599073198881046
# [fold 1]  coeficiente de correlación: 0.5236488849795221
# [fold 2]  coeficiente de correlación: 0.39214902216329595
# [fold 3]  coeficiente de correlación: -0.36752929118418676
# 0.27704398396168395
# Mejor coeficiente previo: 0.2750671535478531
# Coeficiente actual: 0.27704398396168395
# alpha = 0.9200000000000005
# [fold 0]  coeficiente de correlación: 0.5564668973859187
# [fold 1]  coeficiente de correlación: 0.5230332559015602
# [fold 2]  coeficiente de correlación: 0.39031545353505814
# [fold 3]  coeficiente de correlación: -0.3541561272475413
# 0.278914869893749
# Mejor coeficiente previo: 0.27704398396168395
# Coeficiente actual: 0.278914869893749
# alpha = 0.9400000000000005
# [fold 0]  coeficiente de correlación: 0.5529663528000837
# [fold 1]  coeficiente de correlación: 0.522403830302281
# [fold 2]  coeficiente de correlación: 0.3883561277111218
# [fold 3]  coeficiente de correlación: -0.3410063626333244
# 0.28067998704504055
# Mejor coeficiente previo: 0.278914869893749
# Coeficiente actual: 0.28067998704504055
# alpha = 0.9600000000000005
# [fold 0]  coeficiente de correlación: 0.5494056862004759
# [fold 1]  coeficiente de correlación: 0.5217591224645335
# [fold 2]  coeficiente de correlación: 0.38626372517277907
# [fold 3]  coeficiente de correlación: -0.3280794049866982
# 0.28233728221277254
# Mejor coeficiente previo: 0.28067998704504055
# Coeficiente actual: 0.28233728221277254
# alpha = 0.9800000000000005
# [fold 0]  coeficiente de correlación: 0.5457848975156525
# [fold 1]  coeficiente de correlación: 0.5211021477892464
# [fold 2]  coeficiente de correlación: 0.3840457625721103
# [fold 3]  coeficiente de correlación: -0.3153766228218191
# 0.2838890462637975
# Mejor coeficiente previo: 0.28233728221277254
# Coeficiente actual: 0.2838890462637975
# Mejor alpha en promedio 0.9800000000000005 con un coeficiente de correlacion promedio de : 0.2838890462637975
