# %% [markdown]
# # Introducción a Machine Learning
#
# Los procesos principales en Machine Learning  son los siguientes:
# 1. Recolección de datos
#
# 2. Procesamiento de datos
#
# 3. Identificación del modelo
#
# 4. Entrenamiento
#
# 5. Validación
#
# 6. Identificación de hiperparámetros
#
# 7. Predicción
#
#
#
# El proceso de aprendizaje es iterativo, por lo que es común que en cualquier paso nos podamos regresar a otro proceso, siempre con la finalidad de generar el mejor modelo.
#
# En esta práctica partiremos del punto 2, asumiendo que los datos ya están recolectados.

# %% [markdown]
# ## 2. procesamiento de datos

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

diabetes = datasets.load_diabetes()
X = diabetes.data
y = diabetes.target

print('Dimensiones en X = {}'.format(X.shape))
print('Dimensiones en y = {}'.format(y.shape))

# Samples total  442
# Dimensionality  10
# Features  real, -.2 < x < .2
# Targets integer 25 - 346
# Out:
# Dimensiones en X = (442, 10)
# Dimensiones en y = (442,)

# %% [markdown]
# ## 3. Identificación del modelo
#
# En este ejemplo se seleccionará  el modelo Lasso

# %%
from sklearn.linear_model import Lasso

linear_model = Lasso()

# %% [markdown]
# ## 4 y 5. Entrenamiento y Validación

# %%
from sklearn.model_selection import KFold

k_fold = KFold(n_splits=3)

for k, (train, test) in enumerate(k_fold.split(X, y)):
    # Se entrena con el conjunto de datos de entrenamiento
    linear_model.fit(X[train], y[train])
    # Se valida con el conjunto de datos de prueba
    print("[fold {}]  coeficiente de correlación: {}".format(k, linear_model.score(X[test], y[test])))
# Out:
# [fold 0]  coeficiente de correlación: 0.34542984833684853
# [fold 1]  coeficiente de correlación: 0.34712314449919834
# [fold 2]  coeficiente de correlación: 0.36884725706191346

# %% [markdown]
# ## 6. Identificación de hiperparámetros
#
# El modelo Lasso tiene un hiperparámetro que es alpha, por defecto tiene asignado el valor 1.0.
#
# Para identificar de qué forma se deberían modificar los hiperparámetros para aumentar el rendimiento, se debe conocer muy bien el algoritmo.
#
# Esta práctica tiene como objetivo el de conocer los procesos generales en el aprendizaje automático, así que la explicación del modelo está fuera de este ámbito. Sin embargo, se muestra la función objetivo para dar una intuición de cómo afecta éste hiperparámetro en el modelo.
#
# $$ Cost = (1 / (2 * num\_instancias)) * ||y - Xw||^2_2 + alpha * ||w||_1$$

# %%
linear_model2 = Lasso(alpha=0.1)
k_fold = KFold(n_splits=3)

for k, (train, test) in enumerate(k_fold.split(X, y)):
    # Se entrena con el conjunto de datos de entrenamiento
    linear_model2.fit(X[train], y[train])
    # Se valida con el conjunto de datos de prueba
    print("[fold {}]  coeficiente de correlación: {}".format(k, linear_model2.score(X[test], y[test])))
# Out:
# [fold 0]  coeficiente de correlación: 0.4553764654572192
# [fold 1]  coeficiente de correlación: 0.4970449650050526
# [fold 2]  coeficiente de correlación: 0.5075811884365067

# %% [markdown]
# # Ejercicio 1
#
# 1.1 Automatizar la búsqueda del mejor valor de alpha. Por ejemplo, realizar una búsqueda de 50 elementos en el rango [0,1]
#
# Emplear validación cruzada de 4 folds
#
# 1.2 Discutir cómo afecta el número de folds en el proceso de entrenamiento y validación; cuál valor es el adecuado.

# %%
#*EXTRA
def frange(start,stop,step):
    while(start<stop):
        yield start
        start = start+step

# %%
#Ejercicio 1.1 Busqueda del Alpha !!
n = 4
k_fold2 = KFold(n_splits=n)
AALPHA = 0
KALPHA = 0
IALPHA = 0
for i in frange(0.02,1,.02):
    AALPHA = 0
    print("alpha = {}".format(i))
    linear_model3 = Lasso(alpha = i)
    for k2, (train, test) in enumerate(k_fold2.split(X, y)):
        linear_model3.fit(X[train], y[train])
        # Se valida con el conjunto de datos de prueba
        print("[fold {}]  coeficiente de correlación: {}".format(k2, linear_model3.score(X[test], y[test])))
        AALPHA = AALPHA + (linear_model3.score(X[test],y[test]))    
    print(AALPHA/4)
    if(KALPHA == 0):
        KALPHA = (AALPHA/4)
    else:
        if(KALPHA < (AALPHA/4)):
            print("Mejor coeficiente previo: {} ".format(KALPHA))
            print("Coeficiente actual: {} ".format(AALPHA/4))
            IALPHA = i
            KALPHA = (AALPHA/4)
print("Mejor alpha en promedio {} con un coeficiente de correlacion de : {}".format(IALPHA,KALPHA))
# Out:
# alpha = 0.02
# [fold 0]  coeficiente de correlación: 0.6386361584381104
# [fold 1]  coeficiente de correlación: 0.5420141956242923
# [fold 2]  coeficiente de correlación: -1.5756739409366065
# -0.09875589671855095
# alpha = 0.04
# [fold 0]  coeficiente de correlación: 0.6604816288707768
# [fold 1]  coeficiente de correlación: 0.5441728027861938
# [fold 2]  coeficiente de correlación: -1.164022838202662
# 0.010157898363577167
# Mejor coeficiente previo: -0.09875589671855095
# Coeficiente actual: 0.010157898363577167
# alpha = 0.06
# [fold 0]  coeficiente de correlación: 0.6554374208003224
# [fold 1]  coeficiente de correlación: 0.5384133077582318
# [fold 2]  coeficiente de correlación: -0.8191817785631624
# 0.09366723749884795
# Mejor coeficiente previo: 0.010157898363577167
# Coeficiente actual: 0.09366723749884795
# alpha = 0.08
# [fold 0]  coeficiente de correlación: 0.6567892768289585
# [fold 1]  coeficiente de correlación: 0.5247278539322486
# [fold 2]  coeficiente de correlación: -0.5313517303129636
# 0.1625413501120609
# Mejor coeficiente previo: 0.09366723749884795
# Coeficiente actual: 0.1625413501120609
# alpha = 0.1
# [fold 0]  coeficiente de correlación: 0.6578387262554012
# [fold 1]  coeficiente de correlación: 0.5159359720314989
# [fold 2]  coeficiente de correlación: -0.314615425561366
# 0.21478981818138354
# Mejor coeficiente previo: 0.1625413501120609
# Coeficiente actual: 0.21478981818138354
# alpha = 0.12000000000000001
# [fold 0]  coeficiente de correlación: 0.6585858576309278
# [fold 1]  coeficiente de correlación: 0.5063185056317192
# [fold 2]  coeficiente de correlación: -0.17309250922938113
# 0.24795296350831647
# Mejor coeficiente previo: 0.21478981818138354
# Coeficiente actual: 0.24795296350831647
# alpha = 0.14
# [fold 0]  coeficiente de correlación: 0.6590307888949272
# [fold 1]  coeficiente de correlación: 0.4957282137894495
# [fold 2]  coeficiente de correlación: -0.10667141762178244
# 0.26202189626564854
# Mejor coeficiente previo: 0.24795296350831647
# Coeficiente actual: 0.26202189626564854
# alpha = 0.16
# [fold 0]  coeficiente de correlación: 0.6591734724339888
# [fold 1]  coeficiente de correlación: 0.4841739208885578
# [fold 2]  coeficiente de correlación: -0.09872226770463709
# 0.2611562814044774
# alpha = 0.18
# [fold 0]  coeficiente de correlación: 0.6590141996767785
# [fold 1]  coeficiente de correlación: 0.4728644165505461
# [fold 2]  coeficiente de correlación: -0.09524363388973289
# 0.25915874558439794
# alpha = 0.19999999999999998
# [fold 0]  coeficiente de correlación: 0.6585635680989657
# [fold 1]  coeficiente de correlación: 0.4619897990497215
# [fold 2]  coeficiente de correlación: -0.0924756967879703
# 0.2570194175901792
# alpha = 0.21999999999999997
# [fold 0]  coeficiente de correlación: 0.6577962788933207
# [fold 1]  coeficiente de correlación: 0.4509212626244931
# [fold 2]  coeficiente de correlación: -0.09041831470845696
# 0.25457480670233923
# alpha = 0.23999999999999996
# [fold 0]  coeficiente de correlación: 0.6567106891461454
# [fold 1]  coeficiente de correlación: 0.4396593048031138
# [fold 2]  coeficiente de correlación: -0.08907095465064718
# 0.251824759824653
# alpha = 0.25999999999999995
# [fold 0]  coeficiente de correlación: 0.6550938510662884
# [fold 1]  coeficiente de correlación: 0.4282032082899833
# [fold 2]  coeficiente de correlación: -0.08843325744251063
# 0.24871595047844025
# alpha = 0.27999999999999997
# [fold 0]  coeficiente de correlación: 0.6534329920120874
# [fold 1]  coeficiente de correlación: 0.41655128521417484
# [fold 2]  coeficiente de correlación: -0.08844931972091774
# 0.24538373937633612
# alpha = 0.3
# [fold 0]  coeficiente de correlación: 0.6517300917717289
# [fold 1]  coeficiente de correlación: 0.40470299369845064
# [fold 2]  coeficiente de correlación: -0.08889415679881818
# 0.24188473216784034
# alpha = 0.32
# [fold 0]  coeficiente de correlación: 0.6499849841701598
# [fold 1]  coeficiente de correlación: 0.39265838596404756
# [fold 2]  coeficiente de correlación: -0.09000390011545245
# 0.2381598675046887
# alpha = 0.34
# [fold 0]  coeficiente de correlación: 0.6481976692073801
# [fold 1]  coeficiente de correlación: 0.38041750789496775
# [fold 2]  coeficiente de correlación: -0.09177297558181108
# 0.23421055038013416
# alpha = 0.36000000000000004
# [fold 0]  coeficiente de correlación: 0.6463681468833902
# [fold 1]  coeficiente de correlación: 0.3679870020314531
# [fold 2]  coeficiente de correlación: -0.0942061624763526
# 0.23003724660962266
# alpha = 0.38000000000000006
# [fold 0]  coeficiente de correlación: 0.6445388734146962
# [fold 1]  coeficiente de correlación: 0.3572193797228582
# [fold 2]  coeficiente de correlación: -0.09240865472480286
# 0.22733739960318788
# alpha = 0.4000000000000001
# [fold 0]  coeficiente de correlación: 0.6426173171611
# [fold 1]  coeficiente de correlación: 0.35170294047873973
# [fold 2]  coeficiente de correlación: -0.08677338678642244
# 0.22688671771335434
# alpha = 0.4200000000000001
# [fold 0]  coeficiente de correlación: 0.6406513954482651
# [fold 1]  coeficiente de correlación: 0.34611821377621055
# [fold 2]  coeficiente de correlación: -0.08128780442152306
# 0.22637045120073815
# alpha = 0.4400000000000001
# [fold 0]  coeficiente de correlación: 0.638641892539817
# [fold 1]  coeficiente de correlación: 0.34046547797800414
# [fold 2]  coeficiente de correlación: -0.07595194748028944
# 0.2257888557593829
# alpha = 0.46000000000000013
# [fold 0]  coeficiente de correlación: 0.6365370320589795
# [fold 1]  coeficiente de correlación: 0.3347528177561728
# [fold 2]  coeficiente de correlación: -0.07076578265400335
# 0.22513101679028724
# alpha = 0.48000000000000015
# [fold 0]  coeficiente de correlación: 0.6344176362795269
# [fold 1]  coeficiente de correlación: 0.32896174781562
# [fold 2]  coeficiente de correlación: -0.06572925726675938
# 0.22441253170709685
# alpha = 0.5000000000000001
# [fold 0]  coeficiente de correlación: 0.6322728603599606
# [fold 1]  coeficiente de correlación: 0.3230993788020714
# [fold 2]  coeficiente de correlación: -0.06084237068805054
# 0.22363246711849535
# alpha = 0.5200000000000001
# [fold 0]  coeficiente de correlación: 0.630100372226007
# [fold 1]  coeficiente de correlación: 0.31716816617487187
# [fold 2]  coeficiente de correlación: -0.05610512268319568
# 0.2227908539294208
# alpha = 0.5400000000000001
# [fold 0]  coeficiente de correlación: 0.62789794765746
# [fold 1]  coeficiente de correlación: 0.3111808470548556
# [fold 2]  coeficiente de correlación: -0.051517512939325494
# 0.22189032044324752
# alpha = 0.5600000000000002
# [fold 0]  coeficiente de correlación: 0.6256136797740632
# [fold 1]  coeficiente de correlación: 0.30511182579768614
# [fold 2]  coeficiente de correlación: -0.04707954145644244
# 0.22091149102882673
# alpha = 0.5800000000000002
# [fold 0]  coeficiente de correlación: 0.6233775761942548
# [fold 1]  coeficiente de correlación: 0.29897421153724313
# [fold 2]  coeficiente de correlación: -0.042791208234542744
# 0.2198901448742388
# alpha = 0.6000000000000002
# [fold 0]  coeficiente de correlación: 0.6211041912677611
# [fold 1]  coeficiente de correlación: 0.2927674823268205
# [fold 2]  coeficiente de correlación: -0.038652513273628175
# 0.21880479008023834
# alpha = 0.6200000000000002
# [fold 0]  coeficiente de correlación: 0.6187927810608636
# [fold 1]  coeficiente de correlación: 0.28650767955247913
# [fold 2]  coeficiente de correlación: -0.03466342074334117
# 0.21765925996750038
# alpha = 0.6400000000000002
# [fold 0]  coeficiente de correlación: 0.6164406558458673
# [fold 1]  coeficiente de correlación: 0.2801608180845787
# [fold 2]  coeficiente de correlación: -0.030823953588191788
# 0.21644438008556355
# alpha = 0.6600000000000003
# [fold 0]  coeficiente de correlación: 0.6140535799076989
# [fold 1]  coeficiente de correlación: 0.2737658685579125
# [fold 2]  coeficiente de correlación: -0.02713412594756681
# 0.21517133062951116
# alpha = 0.6800000000000003
# [fold 0]  coeficiente de correlación: 0.6116262321727997
# [fold 1]  coeficiente de correlación: 0.2672791059422225
# [fold 2]  coeficiente de correlación: -0.023593937821470238
# 0.21382785007338798
# alpha = 0.7000000000000003
# [fold 0]  coeficiente de correlación: 0.6091613520089951
# [fold 1]  coeficiente de correlación: 0.26072344119818924
# [fold 2]  coeficiente de correlación: -0.020203389209898948
# 0.21242035099932136
# alpha = 0.7200000000000003
# [fold 0]  coeficiente de correlación: 0.6066586480605938
# [fold 1]  coeficiente de correlación: 0.25475518112791384
# [fold 2]  coeficiente de correlación: -0.01696248011285384
# 0.21111283726891344
# alpha = 0.7400000000000003
# [fold 0]  coeficiente de correlación: 0.6041195631910863
# [fold 1]  coeficiente de correlación: 0.25075592972886107
# [fold 2]  coeficiente de correlación: -0.013871210530335798
# 0.2102510705974029
# alpha = 0.7600000000000003
# [fold 0]  coeficiente de correlación: 0.6015410091096421
# [fold 1]  coeficiente de correlación: 0.24864036501671608
# [fold 2]  coeficiente de correlación: -0.010929580462343713
# 0.20981294841600362
# alpha = 0.7800000000000004
# [fold 0]  coeficiente de correlación: 0.5989247239363054
# [fold 1]  coeficiente de correlación: 0.24649781708914345
# [fold 2]  coeficiente de correlación: -0.008137589908879583
# 0.2093212377791423
# alpha = 0.8000000000000004
# [fold 0]  coeficiente de correlación: 0.5962717690967678
# [fold 1]  coeficiente de correlación: 0.24435868867186625
# [fold 2]  coeficiente de correlación: -0.005495238869940522
# 0.2087838047246734
# alpha = 0.8200000000000004
# [fold 0]  coeficiente de correlación: 0.5935794925111657
# [fold 1]  coeficiente de correlación: 0.24221013255968224
# [fold 2]  coeficiente de correlación: -0.0030025273455287493
# 0.2081967744313298
# alpha = 0.8400000000000004
# [fold 0]  coeficiente de correlación: 0.5908505519336084
# [fold 1]  coeficiente de correlación: 0.24003735054228081
# [fold 2]  coeficiente de correlación: -0.0006594553356429333
# 0.20755711178506156
# alpha = 0.8600000000000004
# [fold 0]  coeficiente de correlación: 0.5880820945820091
# [fold 1]  coeficiente de correlación: 0.23786897628751957
# [fold 2]  coeficiente de correlación: 0.0015339771597157048
# 0.2068712620073111
# alpha = 0.8800000000000004
# [fold 0]  coeficiente de correlación: 0.5852770076460904
# [fold 1]  coeficiente de correlación: 0.23569111280282104
# [fold 2]  coeficiente de correlación: 0.0035777701405478313
# 0.20613647264736482
# alpha = 0.9000000000000005
# [fold 0]  coeficiente de correlación: 0.5824339802149834
# [fold 1]  coeficiente de correlación: 0.23348844337397812
# [fold 2]  coeficiente de correlación: 0.005471923606853557
# 0.20534858679895376
# alpha = 0.9200000000000005
# [fold 0]  coeficiente de correlación: 0.5795530507462829
# [fold 1]  coeficiente de correlación: 0.23129082340372886
# [fold 2]  coeficiente de correlación: 0.00722762679016653
# 0.20451787523504458
# alpha = 0.9400000000000005
# [fold 0]  coeficiente de correlación: 0.5766324600161744
# [fold 1]  coeficiente de correlación: 0.2290840451818179
# [fold 2]  coeficiente de correlación: 0.009756064599779957
# 0.20386814244944307
# alpha = 0.9600000000000005
# [fold 0]  coeficiente de correlación: 0.5736755996156262
# [fold 1]  coeficiente de correlación: 0.22685223636632712
# [fold 2]  coeficiente de correlación: 0.012200751085565842
# 0.2031821467668798
# alpha = 0.9800000000000005
# [fold 0]  coeficiente de correlación: 0.5706808641796977
# [fold 1]  coeficiente de correlación: 0.22462572542033632
# [fold 2]  coeficiente de correlación: 0.014568144336012612
# 0.20246868348401165
# Mejor alpha en promedio 0.14 con un coeficiente de correlacion de : 0.26202189626564854

# %% [markdown]
# # Ejercicio 2
#
# Programar los siguientes errores: $sse$, $mse$, $rmse$
#
# Agregar las métricas en el proceso de validación del modelo

# %%
def SSEf(Yr,Yi):
    return (Yr-Yi)**2
    
def SSE(Yr,Yi):
    Sum = 0
    for i in range(0,len(Yr)):
        Sum = Sum + SSEf(Yr[i],Yi[i])    
        

def MSE(Yr,Yi):
    n = len(Yr)
    Y = SSE(Yr,Yi)
    return (Y/n)

# %% [markdown]
# # Ejercicio 3
# Graficar los valores obtenidos por el modelo, con el mejor hiper-parámetro, y los valores reales de cada uno de los folds.

# %% [markdown]
# # Ejercicio 4
#
# Replicar los ejercicios 1, 2 y 3 con el dataset boston.
#
# Ejemplo:

# %%
from sklearn.datasets import load_boston
boston = load_boston()
Z = boston.data
a = boston.target

# %%
n = 4 
k_fold3 = KFold(n_splits=n)
AALPHA = 0
KALPHA = 0
IALPHA = 0
for i in frange(0.02,1,.02):
    AALPHA = 0
    print("alpha = {}".format(i))
    linear_model4 = Lasso(alpha = i)
    for k2, (train, test) in enumerate(k_fold3.split(Z, a)):
        linear_model4.fit(Z[train], a[train])
        # Se valida con el conjunto de datos de prueba
        print("[fold {}]  coeficiente de correlación: {}".format(k2, linear_model4.score(Z[test], a[test])))
        AALPHA = AALPHA + (linear_model4.score(Z[test],a[test]))    
    print(AALPHA/4)
    if(KALPHA == 0):
        KALPHA = (AALPHA/4)
    else:
        if(KALPHA < (AALPHA/4)):
            print("Mejor coeficiente previo: {} ".format(KALPHA))
            print("Coeficiente actual: {} ".format(AALPHA/4))
            IALPHA = i
            KALPHA = (AALPHA/4)
print("Mejor alpha en promedio {} con un coeficiente de correlacion promedio de : {}".format(IALPHA,KALPHA))
# Out:
# alpha = 0.02
# [fold 0]  coeficiente de correlación: 0.6633413096718084
# [fold 1]  coeficiente de correlación: 0.635630844301446
# [fold 2]  coeficiente de correlación: 0.6613704594057834
# [fold 3]  coeficiente de correlación: 0.6321873944274884
# [fold 4]  coeficiente de correlación: 0.5453950782961197
# [fold 5]  coeficiente de correlación: -0.3247250801962971
# [fold 6]  coeficiente de correlación: 0.3489970246999469
# 0.7905492576515739
# alpha = 0.04
# [fold 0]  coeficiente de correlación: 0.6694035481480622
# [fold 1]  coeficiente de correlación: 0.6639731743825339
# [fold 2]  coeficiente de correlación: 0.6354035079412601
# [fold 3]  coeficiente de correlación: 0.6477531155163992
# [fold 4]  coeficiente de correlación: 0.5501092167419295
# [fold 5]  coeficiente de correlación: -0.30718841343455505
# [fold 6]  coeficiente de correlación: 0.28184390307279317
# 0.7853245130921057
# alpha = 0.06
# [fold 0]  coeficiente de correlación: 0.6719397475142541
# [fold 1]  coeficiente de correlación: 0.6811933711557631
# [fold 2]  coeficiente de correlación: 0.633656166814638
# [fold 3]  coeficiente de correlación: 0.6588240151560212
# [fold 4]  coeficiente de correlación: 0.5349455126796445
# [fold 5]  coeficiente de correlación: -0.2903588528332586
# [fold 6]  coeficiente de correlación: 0.2587098491176322
# 0.7872274524011735
# alpha = 0.08
# [fold 0]  coeficiente de correlación: 0.6728088519837869
# [fold 1]  coeficiente de correlación: 0.6843148381361092
# [fold 2]  coeficiente de correlación: 0.6312358073419572
# [fold 3]  coeficiente de correlación: 0.6606890507515556
# [fold 4]  coeficiente de correlación: 0.5313755313124431
# [fold 5]  coeficiente de correlación: -0.273298404503856
# [fold 6]  coeficiente de correlación: 0.25515628717472694
# 0.7905704905491806
# Mejor coeficiente previo: 0.7905492576515739
# Coeficiente actual: 0.7905704905491806
# alpha = 0.1
# [fold 0]  coeficiente de correlación: 0.6735520352071618
# [fold 1]  coeficiente de correlación: 0.684552028672792
# [fold 2]  coeficiente de correlación: 0.6283388952108885
# [fold 3]  coeficiente de correlación: 0.6567860590513438
# [fold 4]  coeficiente de correlación: 0.5273299299450607
# [fold 5]  coeficiente de correlación: -0.2530838264081867
# [fold 6]  coeficiente de correlación: 0.2515024679990697
# 0.7922443974195325
# Mejor coeficiente previo: 0.7905704905491806
# Coeficiente actual: 0.7922443974195325
# alpha = 0.12000000000000001
# [fold 0]  coeficiente de correlación: 0.674096910534769
# [fold 1]  coeficiente de correlación: 0.6843337800481801
# [fold 2]  coeficiente de correlación: 0.6249661997675694
# [fold 3]  coeficiente de correlación: 0.6518214640425953
# [fold 4]  coeficiente de correlación: 0.5228080218499798
# [fold 5]  coeficiente de correlación: -0.23369229381271706
# [fold 6]  coeficiente de correlación: 0.24778195069781994
# 0.7930290082820493
# Mejor coeficiente previo: 0.7922443974195325
# Coeficiente actual: 0.7930290082820493
# alpha = 0.14
# [fold 0]  coeficiente de correlación: 0.6744435281106848
# [fold 1]  coeficiente de correlación: 0.6836600883323714
# [fold 2]  coeficiente de correlación: 0.6211169815127109
# [fold 3]  coeficiente de correlación: 0.6457969050707346
# [fold 4]  coeficiente de correlación: 0.5178087681378503
# [fold 5]  coeficiente de correlación: -0.21514444809072164
# [fold 6]  coeficiente de correlación: 0.24395861712895717
# 0.7929101100506468
# alpha = 0.16
# [fold 0]  coeficiente de correlación: 0.6745922021631413
# [fold 1]  coeficiente de correlación: 0.6825309535253654
# [fold 2]  coeficiente de correlación: 0.6168062114036404
# [fold 3]  coeficiente de correlación: 0.6387103354744954
# [fold 4]  coeficiente de correlación: 0.5123341635697689
# [fold 5]  coeficiente de correlación: -0.19744028924220114
# [fold 6]  coeficiente de correlación: 0.24325483124015915
# 0.7926971020335923
# alpha = 0.18
# [fold 0]  coeficiente de correlación: 0.6745423404357123
# [fold 1]  coeficiente de correlación: 0.6809628589010146
# [fold 2]  coeficiente de correlación: 0.6131726297897426
# [fold 3]  coeficiente de correlación: 0.6306819434473891
# [fold 4]  coeficiente de correlación: 0.5082981100796585
# [fold 5]  coeficiente de correlación: -0.18057981726715355
# [fold 6]  coeficiente de correlación: 0.2473825056646063
# 0.7936151427627425
# Mejor coeficiente previo: 0.7930290082820493
# Coeficiente actual: 0.7936151427627425
# alpha = 0.19999999999999998
# [fold 0]  coeficiente de correlación: 0.6743164662341006
# [fold 1]  coeficiente de correlación: 0.6797044484825912
# [fold 2]  coeficiente de correlación: 0.6095039942081046
# [fold 3]  coeficiente de correlación: 0.6232953866766537
# [fold 4]  coeficiente de correlación: 0.5055374669315813
# [fold 5]  coeficiente de correlación: -0.16456304320946713
# [fold 6]  coeficiente de correlación: 0.2514451626713411
# 0.7948099704987265
# Mejor coeficiente previo: 0.7936151427627425
# Coeficiente actual: 0.7948099704987265
# alpha = 0.21999999999999997
# [fold 0]  coeficiente de correlación: 0.6739854696833427
# [fold 1]  coeficiente de correlación: 0.678400836326299
# [fold 2]  coeficiente de correlación: 0.6057999460021909
# [fold 3]  coeficiente de correlación: 0.6157996276806103
# [fold 4]  coeficiente de correlación: 0.5026254961548299
# [fold 5]  coeficiente de correlación: -0.1494034309438519
# [fold 6]  coeficiente de correlación: 0.25544220061450584
# 0.7956625363794816
# Mejor coeficiente previo: 0.7948099704987265
# Coeficiente actual: 0.7956625363794816
# alpha = 0.23999999999999996
# [fold 0]  coeficiente de correlación: 0.6735525018873914
# [fold 1]  coeficiente de correlación: 0.6770524423086612
# [fold 2]  coeficiente de correlación: 0.6020614609637284
# [fold 3]  coeficiente de correlación: 0.6082342409374168
# [fold 4]  coeficiente de correlación: 0.4995609159515535
# [fold 5]  coeficiente de correlación: -0.13506922559288825
# [fold 6]  coeficiente de correlación: 0.2593733660010369
# 0.7961914256142251
# Mejor coeficiente previo: 0.7956625363794816
# Coeficiente actual: 0.7961914256142251
# alpha = 0.25999999999999995
# [fold 0]  coeficiente de correlación: 0.6730175392187173
# [fold 1]  coeficiente de correlación: 0.6760180542874339
# [fold 2]  coeficiente de correlación: 0.5982880708814728
# [fold 3]  coeficiente de correlación: 0.6005035060043442
# [fold 4]  coeficiente de correlación: 0.49634439514591666
# [fold 5]  coeficiente de correlación: -0.12157750758620756
# [fold 6]  coeficiente de correlación: 0.26323870157294005
# 0.7964581898811542
# Mejor coeficiente previo: 0.7961914256142251
# Coeficiente actual: 0.7964581898811542
# alpha = 0.27999999999999997
# [fold 0]  coeficiente de correlación: 0.6723806055577308
# [fold 1]  coeficiente de correlación: 0.6750467204856757
# [fold 2]  coeficiente de correlación: 0.5944792229499618
# [fold 3]  coeficiente de correlación: 0.592528508827605
# [fold 4]  coeficiente de correlación: 0.49297593062953493
# [fold 5]  coeficiente de correlación: -0.10892832793194773
# [fold 6]  coeficiente de correlación: 0.2670611207759028
# 0.796385945323616
# alpha = 0.3
# [fold 0]  coeficiente de correlación: 0.671641682157756
# [fold 1]  coeficiente de correlación: 0.6740262373092154
# [fold 2]  coeficiente de correlación: 0.5906360587948962
# [fold 3]  coeficiente de correlación: 0.5843705952406701
# [fold 4]  coeficiente de correlación: 0.4894557005618287
# [fold 5]  coeficiente de correlación: -0.09712763684671821
# [fold 6]  coeficiente de correlación: 0.2707948775890042
# 0.795949378701663
# alpha = 0.32
# [fold 0]  coeficiente de correlación: 0.6708015438026904
# [fold 1]  coeficiente de correlación: 0.6726192596056906
# [fold 2]  coeficiente de correlación: 0.5867573597881679
# [fold 3]  coeficiente de correlación: 0.5760529552928919
# [fold 4]  coeficiente de correlación: 0.48578322941131435
# [fold 5]  coeficiente de correlación: -0.08616176797871211
# [fold 6]  coeficiente de correlación: 0.27446268400025486
# 0.7950788159805745
# alpha = 0.34
# [fold 0]  coeficiente de correlación: 0.6698586372828121
# [fold 1]  coeficiente de correlación: 0.671139639607139
# [fold 2]  coeficiente de correlación: 0.5828443938408694
# [fold 3]  coeficiente de correlación: 0.5675755933285671
# [fold 4]  coeficiente de correlación: 0.4819588112008808
# [fold 5]  coeficiente de correlación: -0.07604064206919481
# [fold 6]  coeficiente de correlación: 0.2780645400096532
# 0.7938502433001816
# alpha = 0.36000000000000004
# [fold 0]  coeficiente de correlación: 0.6688137462743444
# [fold 1]  coeficiente de correlación: 0.6696157233901667
# [fold 2]  coeficiente de correlación: 0.578896506822731
# [fold 3]  coeficiente de correlación: 0.558938473413882
# [fold 4]  coeficiente de correlación: 0.47798244593052586
# [fold 5]  coeficiente de correlación: -0.06676178435470814
# [fold 6]  coeficiente de correlación: 0.28160044561720177
# 0.7922713892735358
# alpha = 0.38000000000000006
# [fold 0]  coeficiente de correlación: 0.6676670175697657
# [fold 1]  coeficiente de correlación: 0.6680462160806837
# [fold 2]  coeficiente de correlación: 0.5749130669310741
# [fold 3]  coeficiente de correlación: 0.5501415783771222
# [fold 4]  coeficiente de correlación: 0.47385414004014664
# [fold 5]  coeficiente de correlación: -0.05811468136075959
# [fold 6]  coeficiente de correlación: 0.28507039921388155
# 0.7903944342129786
# alpha = 0.4000000000000001
# [fold 0]  coeficiente de correlación: 0.6664184742624795
# [fold 1]  coeficiente de correlación: 0.6664335325938464
# [fold 2]  coeficiente de correlación: 0.5708953640350403
# [fold 3]  coeficiente de correlación: 0.541184866102401
# [fold 4]  coeficiente de correlación: 0.469573543602581
# [fold 5]  coeficiente de correlación: -0.046929964102948585
# [fold 6]  coeficiente de correlación: 0.2884746004109714
# 0.7890126042260929
# alpha = 0.4200000000000001
# [fold 0]  coeficiente de correlación: 0.665067898881353
# [fold 1]  coeficiente de correlación: 0.6647765358288804
# [fold 2]  coeficiente de correlación: 0.5668420923311144
# [fold 3]  coeficiente de correlación: 0.5323143847267493
# [fold 4]  coeficiente de correlación: 0.4651413084908085
# [fold 5]  coeficiente de correlación: -0.03617338941026915
# [fold 6]  coeficiente de correlación: 0.2920024845764332
# 0.7874928288562674
# alpha = 0.4400000000000001
# [fold 0]  coeficiente de correlación: 0.663230947461303
# [fold 1]  coeficiente de correlación: 0.6630737178830856
# [fold 2]  coeficiente de correlación: 0.5627552575388788
# [fold 3]  coeficiente de correlación: 0.5233016945840547
# [fold 4]  coeficiente de correlación: 0.4603564133021827
# [fold 5]  coeficiente de correlación: -0.02552856939383563
# [fold 6]  coeficiente de correlación: 0.29545867968483486
# 0.785662035265126
# alpha = 0.46000000000000013
# [fold 0]  coeficiente de correlación: 0.6613143571106089
# [fold 1]  coeficiente de correlación: 0.6613278277887646
# [fold 2]  coeficiente de correlación: 0.5587367395736087
# [fold 3]  coeficiente de correlación: 0.51414509771559
# [fold 4]  coeficiente de correlación: 0.4553694020022334
# [fold 5]  coeficiente de correlación: -0.014989401571475325
# [fold 6]  coeficiente de correlación: 0.29887714233289664
# 0.7836952912380568
# alpha = 0.48000000000000015
# [fold 0]  coeficiente de correlación: 0.6593376636965909
# [fold 1]  coeficiente de correlación: 0.6595376621802822
# [fold 2]  coeficiente de correlación: 0.5546869739487899
# [fold 3]  coeficiente de correlación: 0.5048496967302823
# [fold 4]  coeficiente de correlación: 0.4502525162825327
# [fold 5]  coeficiente de correlación: -0.004553491952388855
# [fold 6]  coeficiente de correlación: 0.30220368802507513
# 0.781578677227791
# alpha = 0.5000000000000001
# [fold 0]  coeficiente de correlación: 0.657300829603614
# [fold 1]  coeficiente de correlación: 0.6577033284656679
# [fold 2]  coeficiente de correlación: 0.5506056437711633
# [fold 3]  coeficiente de correlación: 0.49541202508081517
# [fold 4]  coeficiente de correlación: 0.4450057432260596
# [fold 5]  coeficiente de correlación: 0.005781028358066265
# [fold 6]  coeficiente de correlación: 0.30546378754470693
# 0.7793180965125233
# alpha = 0.5200000000000001
# [fold 0]  coeficiente de correlación: 0.6552830101564061
# [fold 1]  coeficiente de correlación: 0.6558226570397847
# [fold 2]  coeficiente de correlación: 0.5464924860264049
# [fold 3]  coeficiente de correlación: 0.48582735825205553
# [fold 4]  coeficiente de correlación: 0.4396745604913148
# [fold 5]  coeficiente de correlación: 0.01602221689466088
# [fold 6]  coeficiente de correlación: 0.30865637271557156
# 0.7769446653940495
# alpha = 0.5400000000000001
# [fold 0]  coeficiente de correlación: 0.6534443155460727
# [fold 1]  coeficiente de correlación: 0.6538995144192647
# [fold 2]  coeficiente de correlación: 0.5423475144983927
# [fold 3]  coeficiente de correlación: 0.47610538921596657
# [fold 4]  coeficiente de correlación: 0.4343785647525716
# [fold 5]  coeficiente de correlación: 0.02615065204534861
# [fold 6]  coeficiente de correlación: 0.31178111428304
# 0.7745267661901643
# alpha = 0.5600000000000002
# [fold 0]  coeficiente de correlación: 0.6515164483774414
# [fold 1]  coeficiente de correlación: 0.6519785217413435
# [fold 2]  coeficiente de correlación: 0.5381704471283046
# [fold 3]  coeficiente de correlación: 0.4662411461561169
# [fold 4]  coeficiente de correlación: 0.4289356067233882
# [fold 5]  coeficiente de correlación: 0.036174028992567164
# [fold 6]  coeficiente de correlación: 0.31486333013545875
# 0.7719698823136553
# alpha = 0.5800000000000002
# [fold 0]  coeficiente de correlación: 0.6495000084729108
# [fold 1]  coeficiente de correlación: 0.6500541491745286
# [fold 2]  coeficiente de correlación: 0.5339618655105047
# [fold 3]  coeficiente de correlación: 0.4562345787851628
# [fold 4]  coeficiente de correlación: 0.42334852521428123
# [fold 5]  coeficiente de correlación: 0.046092000103936326
# [fold 6]  coeficiente de correlación: 0.31784979846991634
# 0.7692602314328102
# alpha = 0.6000000000000002
# [fold 0]  coeficiente de correlación: 0.647395063367856
# [fold 1]  coeficiente de correlación: 0.6481039440842244
# [fold 2]  coeficiente de correlación: 0.5297214738438292
# [fold 3]  coeficiente de correlación: 0.4460798610437151
# [fold 4]  coeficiente de correlación: 0.4176159730523775
# [fold 5]  coeficiente de correlación: 0.05590403154230483
# [fold 6]  coeficiente de correlación: 0.32076738360870205
# 0.7663969326357523
# alpha = 0.6200000000000002
# [fold 0]  coeficiente de correlación: 0.6452015514703902
# [fold 1]  coeficiente de correlación: 0.6461240022447878
# [fold 2]  coeficiente de correlación: 0.5254492721282781
# [fold 3]  coeficiente de correlación: 0.43578890776742196
# [fold 4]  coeficiente de correlación: 0.4117379653469655
# [fold 5]  coeficiente de correlación: 0.06561037182761231
# [fold 6]  coeficiente de correlación: 0.3236156773409927
# 0.7633819370316122
# alpha = 0.6400000000000002
# [fold 0]  coeficiente de correlación: 0.6429194155667738
# [fold 1]  coeficiente de correlación: 0.6441139060052719
# [fold 2]  coeficiente de correlación: 0.5211452603638509
# [fold 3]  coeficiente de correlación: 0.4253558794761304
# [fold 4]  coeficiente de correlación: 0.4057144064836477
# [fold 5]  coeficiente de correlación: 0.07521070299595667
# [fold 6]  coeficiente de correlación: 0.32639459043021624
# 0.760213540330462
# alpha = 0.6600000000000003
# [fold 0]  coeficiente de correlación: 0.6405487079561025
# [fold 1]  coeficiente de correlación: 0.6420782656106012
# [fold 2]  coeficiente de correlación: 0.5168094356441304
# [fold 3]  coeficiente de correlación: 0.41478069811229756
# [fold 4]  coeficiente de correlación: 0.39954526828444326
# [fold 5]  coeficiente de correlación: 0.08470513004396185
# [fold 6]  coeficiente de correlación: 0.32910436062516946
# 0.7568929665691766
# alpha = 0.6800000000000003
# [fold 0]  coeficiente de correlación: 0.638089428638376
# [fold 1]  coeficiente de correlación: 0.6400118256087142
# [fold 2]  coeficiente de correlación: 0.512441800791035
# [fold 3]  coeficiente de correlación: 0.40405607123520393
# [fold 4]  coeficiente de correlación: 0.3932305769099438
# [fold 5]  coeficiente de correlación: 0.09409344198152103
# [fold 6]  coeficiente de correlación: 0.33174498792585194
# 0.7534170332726614
# alpha = 0.7000000000000003
# [fold 0]  coeficiente de correlación: 0.6355415776135941
# [fold 1]  coeficiente de correlación: 0.6379171045391421
# [fold 2]  coeficiente de correlación: 0.5080420999902011
# [fold 3]  coeficiente de correlación: 0.39319653640231433
# [fold 4]  coeficiente de correlación: 0.38677034922549935
# [fold 5]  coeficiente de correlación: 0.1033757616501364
# [fold 6]  coeficiente de correlación: 0.33431647233226747
# 0.7497899754382887
# alpha = 0.7200000000000003
# [fold 0]  coeficiente de correlación: 0.6329051548817577
# [fold 1]  coeficiente de correlación: 0.6357969440557738
# [fold 2]  coeficiente de correlación: 0.5036108607009753
# [fold 3]  coeficiente de correlación: 0.38615798993521727
# [fold 4]  coeficiente de correlación: 0.3801646161702327
# [fold 5]  coeficiente de correlación: 0.11255189871218152
# [fold 6]  coeficiente de correlación: 0.33681881384441337
# 0.7470015695751379
# alpha = 0.7400000000000003
# [fold 0]  coeficiente de correlación: 0.6301801856689291
# [fold 1]  coeficiente de correlación: 0.6336454593799183
# [fold 2]  coeficiente de correlación: 0.49914781123811847
# [fold 3]  coeficiente de correlación: 0.3831361576672886
# [fold 4]  coeficiente de correlación: 0.37341342512270315
# [fold 5]  coeficiente de correlación: 0.12162191905657882
# [fold 6]  coeficiente de correlación: 0.3392520124622887
# 0.7450992426489563
# alpha = 0.7600000000000003
# [fold 0]  coeficiente de correlación: 0.6273666740691792
# [fold 1]  coeficiente de correlación: 0.6314654455337128
# [fold 2]  coeficiente de correlación: 0.4946529531979288
# [fold 3]  coeficiente de correlación: 0.38009130234315003
# [fold 4]  coeficiente de correlación: 0.36651673955071234
# [fold 5]  coeficiente de correlación: 0.1305857020283444
# [fold 6]  coeficiente de correlación: 0.34161606818589485
# 0.7430737212272306
# alpha = 0.7800000000000004
# [fold 0]  coeficiente de correlación: 0.6244645726467666
# [fold 1]  coeficiente de correlación: 0.629256897988733
# [fold 2]  coeficiente de correlación: 0.4901262860405947
# [fold 3]  coeficiente de correlación: 0.3770113649360656
# [fold 4]  coeficiente de correlación: 0.3594710250933339
# [fold 5]  coeficiente de correlación: 0.13944334424515004
# [fold 6]  coeficiente de correlación: 0.343911104902536
# 0.7409211489632949
# alpha = 0.8000000000000004
# [fold 0]  coeficiente de correlación: 0.6214738650758527
# [fold 1]  coeficiente de correlación: 0.6270198167449793
# [fold 2]  coeficiente de correlación: 0.4855678084664742
# [fold 3]  coeficiente de correlación: 0.37389610251370387
# [fold 4]  coeficiente de correlación: 0.3522830783595325
# [fold 5]  coeficiente de correlación: 0.14819495595026233
# [fold 6]  coeficiente de correlación: 0.3461650154341523
# 0.7386501606362393
# alpha = 0.8200000000000004
# [fold 0]  coeficiente de correlación: 0.6183945948863969
# [fold 1]  coeficiente de correlación: 0.6247542322587101
# [fold 2]  coeficiente de correlación: 0.4809772917837907
# [fold 3]  coeficiente de correlación: 0.3707326112821264
# [fold 4]  coeficiente de correlación: 0.3449495920504486
# [fold 5]  coeficiente de correlación: 0.15684045850163064
# [fold 6]  coeficiente de correlación: 0.3483214736999608
# 0.7362425636157661
# alpha = 0.8400000000000004
# [fold 0]  coeficiente de correlación: 0.6152059975206419
# [fold 1]  coeficiente de correlación: 0.6224601602528425
# [fold 2]  coeficiente de correlación: 0.47635520688158706
# [fold 3]  coeficiente de correlación: 0.36754738777324647
# [fold 4]  coeficiente de correlación: 0.3374705941098709
# [fold 5]  coeficiente de correlación: 0.16537948916274392
# [fold 6]  coeficiente de correlación: 0.3504087871229363
# 0.7337069057059672
# alpha = 0.8600000000000004
# [fold 0]  coeficiente de correlación: 0.6119123582009424
# [fold 1]  coeficiente de correlación: 0.620141289480642
# [fold 2]  coeficiente de correlación: 0.47170131146575167
# [fold 3]  coeficiente de correlación: 0.36432703595149823
# [fold 4]  coeficiente de correlación: 0.3298460415602726
# [fold 5]  coeficiente de correlación: 0.17381233379569594
# [fold 6]  coeficiente de correlación: 0.35242695570307847
# 0.7310418315394702
# alpha = 0.8800000000000004
# [fold 0]  coeficiente de correlación: 0.6085266072465614
# [fold 1]  coeficiente de correlación: 0.6177901673783139
# [fold 2]  coeficiente de correlación: 0.4670156055362835
# [fold 3]  coeficiente de correlación: 0.36107125996797607
# [fold 4]  coeficiente de correlación: 0.3220759433867506
# [fold 5]  coeficiente de correlación: 0.18213899240048648
# [fold 6]  coeficiente de correlación: 0.3543758628909723
# 0.7282486097018359
# alpha = 0.9000000000000005
# [fold 0]  coeficiente de correlación: 0.6050467999273861
# [fold 1]  coeficiente de correlación: 0.6154105123693239
# [fold 2]  coeficiente de correlación: 0.4622980890931822
# [fold 3]  coeficiente de correlación: 0.3577803929902665
# [fold 4]  coeficiente de correlación: 0.31416032791809034
# [fold 5]  coeficiente de correlación: 0.19035946497711587
# [fold 6]  coeficiente de correlación: 0.3562555870481353
# 0.7253277935808751
# alpha = 0.9200000000000005
# [fold 0]  coeficiente de correlación: 0.6014761096006562
# [fold 1]  coeficiente de correlación: 0.6130023234926893
# [fold 2]  coeficiente de correlación: 0.4575485610140416
# [fold 3]  coeficiente de correlación: 0.35444068841344145
# [fold 4]  coeficiente de correlación: 0.30609922817281243
# [fold 5]  coeficiente de correlación: 0.19847375152558389
# [fold 6]  coeficiente de correlación: 0.358066271314056
# 0.7222767333833202
# alpha = 0.9400000000000005
# [fold 0]  coeficiente de correlación: 0.5978110424850755
# [fold 1]  coeficiente de correlación: 0.6105656006086077
# [fold 2]  coeficiente de correlación: 0.45380721126516727
# [fold 3]  coeficiente de correlación: 0.35108027268051123
# [fold 4]  coeficiente de correlación: 0.2978926364742174
# [fold 5]  coeficiente de correlación: 0.2064818520458903
# [fold 6]  coeficiente de correlación: 0.3598079995053458
# 0.7193616537662038
# alpha = 0.9600000000000005
# [fold 0]  coeficiente de correlación: 0.594055463581208
# [fold 1]  coeficiente de correlación: 0.6081003447478639
# [fold 2]  coeficiente de correlación: 0.45283694897175975
# [fold 3]  coeficiente de correlación: 0.3476847800062707
# [fold 4]  coeficiente de correlación: 0.28954053124532864
# [fold 5]  coeficiente de correlación: 0.21438376653803537
# [fold 6]  coeficiente de correlación: 0.36148058007456574
# 0.7170206037912581
# alpha = 0.9800000000000005
# [fold 0]  coeficiente de correlación: 0.5902051784550963
# [fold 1]  coeficiente de correlación: 0.6056065559104574
# [fold 2]  coeficiente de correlación: 0.45185221391088926
# [fold 3]  coeficiente de correlación: 0.344254158886198
# [fold 4]  coeficiente de correlación: 0.2810428654023379
# [fold 5]  coeficiente de correlación: 0.22216905041675472
# [fold 6]  coeficiente de correlación: 0.3630840130217178
# 0.7145535090008628
# Mejor alpha en promedio 0.25999999999999995 con un coeficiente de correlacion promedio de : 0.7964581898811542
