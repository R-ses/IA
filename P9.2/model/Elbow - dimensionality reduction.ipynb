# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.preprocessing import StandardScaler

#importing the Iris dataset with pandas
dataset = pd.read_csv('../dataset/Datset1.csv', header=None)

scaler = StandardScaler()

dataset.loc[:] = scaler.fit_transform(dataset.loc[:])

x = dataset
#x = dataset.iloc[:, [1, 2, 3, 4]].values
# Out:
# /home/raul/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/raul/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
x.head(10)
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.518613 -0.562250  0.232053 -1.169593  1.913905  0.808997  1.034819
# 1  0.246290 -0.499413 -0.827996 -2.490847  0.018145  0.568648  0.733629
# 2  0.196879  0.021231  1.109334 -0.268738  0.088358  0.808997  1.215533
# 3  1.691550 -0.346811  0.487926 -0.809251  0.930918  2.491446  1.466525
# 4  0.295700  0.227694  1.840403  0.451946  1.281985  0.808997  0.663351
# 5  1.481555 -0.517367  0.305159 -1.289707  0.860705  1.562093  1.366128
# 6  1.716255 -0.418624  0.305159 -1.469878 -0.262708  0.328298  0.492677
# 7  1.308617 -0.167278  0.890014 -0.569023  1.492625  0.488531  0.482637
# 8  2.259772 -0.625086 -0.718336 -1.650049 -0.192495  0.808997  0.954502
# 9  1.061565 -0.885409 -0.352802 -1.049479 -0.122282  1.097417  1.125176
#
#          7         8         9         10        11        12
# 0 -0.659563  1.224884  0.251717  0.362177  1.847920  1.013009
# 1 -0.820719 -0.544721 -0.293321  0.406051  1.113449  0.965242
# 2 -0.498407  2.135968  0.269020  0.318304  0.788587  1.395148
# 3 -0.981875  1.032155  1.186068 -0.427544  1.184071  2.334574
# 4  0.226796  0.401404 -0.319276  0.362177  0.449601 -0.037874
# 5 -0.176095  0.664217  0.731870  0.406051  0.336606  2.239039
# 6 -0.498407  0.681738  0.083015  0.274431  1.367689  1.729520
# 7 -0.417829 -0.597284 -0.003499  0.449924  1.367689  1.745442
# 8 -0.578985  0.681738  0.061386  0.537671  0.336606  0.949319
# 9 -1.143031  0.453967  0.935177  0.230557  1.325316  0.949319

# %%
#Finding the optimum number of clusters for k-means classification
from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
    
#Plotting the results onto a line graph, allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()
